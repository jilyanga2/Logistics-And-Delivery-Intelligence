# %% [markdown]
# # Inspecting Customer and Cleaning

# %%
import pandas as pd
customers = pd.read_csv("supplyguard_data/customers.csv")
customers
# Out:
#        customer_id     customer_name customer_type       province  \
# 0          C000001       Sipho Adams      Business        Gauteng
# 1          C000002     Amanda Maseko      Business        Gauteng
# 2          C000003     Karabo Mkhize    Individual        Limpopo
# 3          C000004   Bongani Sithole    Individual  KwaZulu-Natal
# 4          C000005   Bongani Dlamini      Business   Eastern Cape
# ...            ...               ...           ...            ...
# 100195     C050453    Tshepo Mokoena    Enterprise        Gauteng
# 100196     C090710  Phumzile Van Wyk    Individual        Limpopo
# 100197     C052885       Mandla Moyo    Individual   Western Cape
# 100198     C030964       Mpho Pillay    Individual   Western Cape
# 100199     C034574      Kagiso Botha    Individual   Eastern Cape
#
#                 city registration_date  monthly_shipping_budget
# 0          Centurion        2024-10-13                  3530.20
# 1       Johannesburg        2022-01-26                  1555.50
# 2          Polokwane        2019-03-04                 13767.67
# 3       Richards Bay        2021-06-30                 10034.40
# 4        East London        2026-03-28                  7054.38
# ...              ...               ...                      ...
# 100195     Centurion        2021-02-20                  8794.30
# 100196     Polokwane        2025-02-01                 19299.14
# 100197     Worcester        2024-01-15                 23989.65
# 100198  Stellenbosch        2021-05-18                   956.39
# 100199      Gqeberha        2026-02-25                 86176.34
#
# [100200 rows x 7 columns]

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100200 entries, 0 to 100199
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   customer_id              100200 non-null  object
#  1   customer_name            100200 non-null  object
#  2   customer_type            100200 non-null  object
#  3   province                 100200 non-null  object
#  4   city                     99169 non-null   object
#  5   registration_date        100200 non-null  object
#  6   monthly_shipping_budget  99209 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 5.4+ MB

# %%
# Checking for duplicates
customers[customers.duplicated() == True]
# Out:
#        customer_id     customer_name customer_type       province  \
# 100000     C075722   Lindelwa Naidoo    Enterprise        Limpopo
# 100001     C080185     Amanda Maseko    Individual     Mpumalanga
# 100002     C019865   Bongani Mokoena    Individual     Mpumalanga
# 100003     C076700     Mandla Pillay      Business   Western Cape
# 100004     C092992    Bongani Pillay    Individual  KwaZulu-Natal
# ...            ...               ...           ...            ...
# 100195     C050453    Tshepo Mokoena    Enterprise        Gauteng
# 100196     C090710  Phumzile Van Wyk    Individual        Limpopo
# 100197     C052885       Mandla Moyo    Individual   Western Cape
# 100198     C030964       Mpho Pillay    Individual   Western Cape
# 100199     C034574      Kagiso Botha    Individual   Eastern Cape
#
#                 city registration_date  monthly_shipping_budget
# 100000   Thohoyandou        2026-03-26                  4938.25
# 100001      Mbombela        2023-02-01                 10775.52
# 100002      Mbombela        2018-12-25                  6567.96
# 100003     Cape Town        2019-03-02                136120.93
# 100004  Richards Bay        2024-01-01                  4799.09
# ...              ...               ...                      ...
# 100195     Centurion        2021-02-20                  8794.30
# 100196     Polokwane        2025-02-01                 19299.14
# 100197     Worcester        2024-01-15                 23989.65
# 100198  Stellenbosch        2021-05-18                   956.39
# 100199      Gqeberha        2026-02-25                 86176.34
#
# [200 rows x 7 columns]

# %%
#Removing duplicates
customers = customers.drop_duplicates()

# %%
#Changing date from object to datetime
customers['registration_date'] = pd.to_datetime(customers['registration_date'])
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\2841362927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['registration_date'] = pd.to_datetime(customers['registration_date'])

# %%
#Changing the NaT to Nan
customers['monthly_shipping_budget'] = pd.to_numeric(
customers['monthly_shipping_budget'],
errors='coerce'
)
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\1203537362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['monthly_shipping_budget'] = pd.to_numeric(

# %%
#Changing the money from object to float
customers['monthly_shipping_budget'] = pd.to_numeric(customers['monthly_shipping_budget'])
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\52773667.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['monthly_shipping_budget'] = pd.to_numeric(customers['monthly_shipping_budget'])

# %%
customers.monthly_shipping_budget
# Out:
# 0         3530.20
# 1         1555.50
# 2        13767.67
# 3        10034.40
# 4         7054.38
#            ...
# 99995    78517.63
# 99996     7369.63
# 99997     9942.18
# 99998      838.25
# 99999    69674.92
# Name: monthly_shipping_budget, Length: 100000, dtype: float64

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'customer_type', 'province', 'city',
#        'registration_date', 'monthly_shipping_budget'],
#       dtype='object')

# %%
customers.customer_name.unique()
# Out:
# array(['Sipho Adams', 'Amanda Maseko', 'Karabo Mkhize', 'Bongani Sithole',
#        'Bongani Dlamini', 'Nokuthula Naidoo', 'Sipho Maseko',
#        'Lindelwa Khumalo', 'Mpho Molefe', 'Sipho Mabena',
#        'Busisiwe Mabena', 'Dumisani Ngcobo', 'Siyabonga Khumalo',
#        'Amanda Cele', 'Lindelwa Mabena', 'Amanda Mokoena',
#        'Themba Naidoo', 'Nomsa Van Wyk', 'Mandla Mthembu',
#        'Precious Ndlovu', 'Themba Mkhize', 'Zanele Williams',
#        'Ayanda Mthembu', 'Phumzile Modise', 'Karabo Mthembu',
#        'Bongani Ngcobo', 'Mandla Ngcobo', 'Busisiwe Sithole',
#        'Precious Naidoo', 'Precious Molefe', 'Mpho Moyo', 'Sipho Nkosi',
#        'Busisiwe Van Wyk', 'Kabelo Botha', 'Lerato Sithole',
#        'Nokuthula Mokoena', 'Mandla Moyo', 'Lwazi Mkhize', 'Tshepo Zulu',
#        'Ayanda Khumalo', 'Siyabonga Mahlangu', 'Lindelwa Pillay',
#        'Sibusiso Mabena', 'Lerato Ndlovu', 'Dumisani Williams',
#        'Precious Zulu', 'Kabelo Mokoena', 'Karabo Jacobs', 'Amanda Adams',
#        'Siyabonga Botha', 'Ayanda Dlamini', 'Zanele Sithole',
#        'Precious Nkosi', 'Lerato Moyo', 'Busisiwe Mthembu',
#        'Nomsa Pillay', 'Siyabonga Ngcobo', 'Lindelwa Cele',
#        'Siyabonga Adams', 'Zanele Mthembu', 'Bongani Adams',
#        'Sibusiso Mthembu', 'Kabelo Mabena', 'Zanele Cele',
#        'Precious Modise', 'Amanda Mahlangu', 'Ayanda Nkosi',
#        'Precious Mthembu', 'Nomsa Ndlovu', 'Lindelwa Mokoena',
#        'Precious Adams', 'Sibusiso Nkosi', 'Mpho Ngcobo', 'Kagiso Pillay',
#        'Karabo Mahlangu', 'Phumzile Sithole', 'Bongani Cele',
#        'Ayanda Maseko', 'Mandla Modise', 'Tshepo Nkosi', 'Lindelwa Nkosi',
#        'Sipho Sithole', 'Nandi Mokoena', 'Amanda Mkhize', 'Mandla Mabena',
#        'Mandla Cele', 'Nokuthula Van Wyk', 'Zanele Khumalo',
#        'Kabelo Williams', 'Nandi Mkhize', 'Mpho Botha', 'Lindelwa Mkhize',
#        'Tshepo Williams', 'Nomsa Naidoo', 'Mandla Adams',
#        'Ayanda Sithole', 'Mandla Maseko', 'Thabo Nkosi', 'Amanda Zulu',
#        'Amanda Williams', 'Karabo Van Wyk', 'Precious Mokoena',
#        'Lwazi Mabena', 'Amanda Sithole', 'Busisiwe Nkosi', 'Themba Botha',
#        'Kagiso Mahlangu', 'Thabo Mahlangu', 'Lwazi Williams',
#        'Bongani Naidoo', 'Karabo Khumalo', 'Nokuthula Zulu',
#        'Kagiso Dlamini', 'Lerato Cele', 'Amanda Dlamini', 'Kagiso Moyo',
#        'Tshepo Cele', 'Busisiwe Mokoena', 'Sipho Mokoena',
#        'Busisiwe Jacobs', 'Nandi Cele', 'Tshepo Adams', 'Thabo Mthembu',
#        'Sibusiso Zulu', 'Dumisani Sithole', 'Mpho Dlamini',
#        'Bongani Mabena', 'Thabo Dlamini', 'Mpho Mahlangu',
#        'Mandla Dlamini', 'Nokuthula Modise', 'Nandi Modise',
#        'Kabelo Mthembu', 'Nandi Sithole', 'Bongani Nkosi',
#        'Karabo Ngcobo', 'Amanda Ndlovu', 'Dumisani Naidoo',
#        'Karabo Adams', 'Bongani Mkhize', 'Bongani Pillay',
#        'Mandla Khumalo', 'Sibusiso Williams', 'Sibusiso Mokoena',
#        'Thabo Mkhize', 'Sipho Pillay', 'Siyabonga Moyo', 'Lindelwa Botha',
#        'Precious Cele', 'Lindelwa Mahlangu', 'Kabelo Mahlangu',
#        'Themba Mokoena', 'Phumzile Nkosi', 'Nomsa Mkhize', 'Themba Adams',
#        'Lindelwa Zulu', 'Zanele Mkhize', 'Mpho Mokoena', 'Nandi Pillay',
#        'Lindelwa Sithole', 'Tshepo Ndlovu', 'Tshepo Mokoena',
#        'Phumzile Khumalo', 'Sipho Mkhize', 'Sibusiso Botha',
#        'Sibusiso Modise', 'Dumisani Adams', 'Kabelo Cele',
#        'Lwazi Mahlangu', 'Dumisani Jacobs', 'Lwazi Van Wyk',
#        'Amanda Mthembu', 'Lwazi Khumalo', 'Amanda Ngcobo',
#        'Precious Maseko', 'Siyabonga Mkhize', 'Lwazi Molefe',
#        'Lerato Van Wyk', 'Sipho Van Wyk', 'Precious Dlamini',
#        'Kabelo Maseko', 'Nomsa Mahlangu', 'Lindelwa Mthembu',
#        'Mpho Ndlovu', 'Siyabonga Ndlovu', 'Nandi Williams',
#        'Nokuthula Maseko', 'Thabo Sithole', 'Siyabonga Mokoena',
#        'Themba Van Wyk', 'Karabo Mabena', 'Bongani Maseko',
#        'Nandi Khumalo', 'Nomsa Molefe', 'Kagiso Williams',
#        'Sipho Mthembu', 'Bongani Modise', 'Amanda Naidoo',
#        'Lerato Molefe', 'Ayanda Pillay', 'Themba Jacobs',
#        'Nomsa Williams', 'Karabo Ndlovu', 'Sipho Modise', 'Ayanda Moyo',
#        'Kagiso Modise', 'Amanda Mabena', 'Nandi Ngcobo',
#        'Phumzile Naidoo', 'Kagiso Ngcobo', 'Precious Mahlangu',
#        'Sibusiso Jacobs', 'Tshepo Mkhize', 'Kagiso Adams', 'Nandi Ndlovu',
#        'Thabo Molefe', 'Nomsa Maseko', 'Phumzile Botha', 'Bongani Jacobs',
#        'Themba Sithole', 'Precious Ngcobo', 'Amanda Pillay',
#        'Lerato Williams', 'Sipho Ngcobo', 'Lwazi Maseko',
#        'Themba Mahlangu', 'Karabo Zulu', 'Precious Williams',
#        'Phumzile Mkhize', 'Ayanda Modise', 'Kagiso Van Wyk',
#        'Mandla Botha', 'Phumzile Mabena', 'Busisiwe Adams',
#        'Busisiwe Modise', 'Bongani Khumalo', 'Thabo Pillay',
#        'Zanele Moyo', 'Mandla Ndlovu', 'Busisiwe Naidoo', 'Nandi Jacobs',
#        'Sipho Khumalo', 'Karabo Modise', 'Siyabonga Molefe',
#        'Phumzile Moyo', 'Sibusiso Mkhize', 'Tshepo Ngcobo',
#        'Kabelo Modise', 'Dumisani Zulu', 'Mpho Cele', 'Mpho Maseko',
#        'Thabo Mabena', 'Nomsa Modise', 'Busisiwe Molefe',
#        'Zanele Dlamini', 'Precious Mkhize', 'Dumisani Mthembu',
#        'Nandi Mabena', 'Mpho Naidoo', 'Phumzile Mokoena', 'Themba Cele',
#        'Dumisani Van Wyk', 'Phumzile Maseko', 'Ayanda Molefe',
#        'Ayanda Ndlovu', 'Nandi Mahlangu', 'Dumisani Khumalo',
#        'Dumisani Modise', 'Nomsa Khumalo', 'Nokuthula Mabena',
#        'Mpho Nkosi', 'Sipho Dlamini', 'Themba Mthembu', 'Precious Moyo',
#        'Amanda Khumalo', 'Sibusiso Ndlovu', 'Bongani Mthembu',
#        'Kabelo Ngcobo', 'Siyabonga Nkosi', 'Lwazi Ngcobo', 'Nomsa Nkosi',
#        'Lerato Naidoo', 'Kabelo Van Wyk', 'Nomsa Zulu',
#        'Siyabonga Mthembu', 'Zanele Molefe', 'Kagiso Naidoo',
#        'Nokuthula Nkosi', 'Lerato Mokoena', 'Ayanda Mabena', 'Nandi Moyo',
#        'Dumisani Nkosi', 'Dumisani Botha', 'Nomsa Mokoena',
#        'Phumzile Van Wyk', 'Ayanda Van Wyk', 'Mpho Sithole',
#        'Lwazi Jacobs', 'Nomsa Adams', 'Thabo Williams', 'Themba Modise',
#        'Bongani Ndlovu', 'Nokuthula Moyo', 'Mandla Jacobs',
#        'Thabo Naidoo', 'Lindelwa Naidoo', 'Siyabonga Naidoo',
#        'Bongani Molefe', 'Kagiso Zulu', 'Zanele Maseko', 'Nomsa Mthembu',
#        'Themba Mabena', 'Phumzile Zulu', 'Busisiwe Zulu', 'Nandi Molefe',
#        'Themba Maseko', 'Busisiwe Pillay', 'Tshepo Naidoo',
#        'Nokuthula Mahlangu', 'Siyabonga Van Wyk', 'Nomsa Cele',
#        'Siyabonga Cele', 'Ayanda Adams', 'Mandla Nkosi',
#        'Precious Van Wyk', 'Tshepo Botha', 'Nokuthula Mthembu',
#        'Sipho Naidoo', 'Mandla Sithole', 'Lwazi Moyo', 'Precious Pillay',
#        'Mpho Van Wyk', 'Busisiwe Khumalo', 'Tshepo Jacobs',
#        'Phumzile Molefe', 'Tshepo Molefe', 'Nandi Naidoo',
#        'Bongani Van Wyk', 'Sipho Williams', 'Zanele Ngcobo',
#        'Bongani Zulu', 'Sipho Moyo', 'Karabo Moyo', 'Nokuthula Jacobs',
#        'Mpho Pillay', 'Dumisani Cele', 'Mandla Molefe', 'Kabelo Moyo',
#        'Precious Sithole', 'Kagiso Botha', 'Sibusiso Maseko',
#        'Nandi Dlamini', 'Kabelo Adams', 'Kagiso Jacobs', 'Nomsa Dlamini',
#        'Nandi Van Wyk', 'Thabo Botha', 'Lindelwa Jacobs', 'Lerato Zulu',
#        'Ayanda Ngcobo', 'Lerato Maseko', 'Bongani Botha', 'Dumisani Moyo',
#        'Siyabonga Zulu', 'Nokuthula Ndlovu', 'Busisiwe Ndlovu',
#        'Themba Khumalo', 'Lwazi Nkosi', 'Karabo Pillay', 'Kagiso Khumalo',
#        'Lerato Khumalo', 'Phumzile Pillay', 'Kabelo Pillay',
#        'Mandla Mokoena', 'Mandla Zulu', 'Dumisani Mabena',
#        'Mandla Van Wyk', 'Tshepo Khumalo', 'Dumisani Dlamini',
#        'Amanda Modise', 'Lwazi Naidoo', 'Bongani Moyo', 'Ayanda Williams',
#        'Tshepo Maseko', 'Sibusiso Van Wyk', 'Sibusiso Mahlangu',
#        'Lindelwa Modise', 'Mpho Mabena', 'Nandi Zulu',
#        'Phumzile Mahlangu', 'Themba Pillay', 'Busisiwe Moyo',
#        'Lerato Modise', 'Thabo Jacobs', 'Mpho Williams', 'Kagiso Mabena',
#        'Tshepo Van Wyk', 'Sipho Cele', 'Tshepo Mahlangu', 'Kagiso Ndlovu',
#        'Busisiwe Botha', 'Phumzile Ndlovu', 'Ayanda Botha',
#        'Kagiso Sithole', 'Dumisani Ndlovu', 'Amanda Jacobs',
#        'Phumzile Adams', 'Sipho Botha', 'Kagiso Mokoena', 'Ayanda Jacobs',
#        'Kagiso Nkosi', 'Thabo Maseko', 'Precious Khumalo',
#        'Karabo Williams', 'Busisiwe Cele', 'Phumzile Jacobs',
#        'Themba Ngcobo', 'Siyabonga Maseko', 'Karabo Naidoo',
#        'Phumzile Dlamini', 'Sibusiso Cele', 'Zanele Nkosi',
#        'Busisiwe Dlamini', 'Nandi Maseko', 'Dumisani Maseko',
#        'Sipho Mahlangu', 'Busisiwe Maseko', 'Siyabonga Pillay',
#        'Ayanda Cele', 'Phumzile Cele', 'Zanele Naidoo', 'Amanda Botha',
#        'Tshepo Dlamini', 'Sipho Jacobs', 'Nokuthula Pillay',
#        'Precious Jacobs', 'Siyabonga Williams', 'Nandi Nkosi',
#        'Thabo Cele', 'Nokuthula Molefe', 'Karabo Maseko', 'Kabelo Zulu',
#        'Lwazi Botha', 'Nokuthula Khumalo', 'Kabelo Dlamini',
#        'Kabelo Khumalo', 'Thabo Adams', 'Mandla Mkhize',
#        'Dumisani Mokoena', 'Nokuthula Mkhize', 'Lwazi Pillay',
#        'Lerato Dlamini', 'Karabo Nkosi', 'Amanda Nkosi', 'Mandla Pillay',
#        'Nomsa Ngcobo', 'Siyabonga Sithole', 'Ayanda Mahlangu',
#        'Lerato Jacobs', 'Lerato Mabena', 'Lindelwa Maseko', 'Zanele Zulu',
#        'Sipho Zulu', 'Zanele Mahlangu', 'Amanda Van Wyk', 'Lwazi Modise',
#        'Nandi Adams', 'Kagiso Maseko', 'Nomsa Sithole', 'Themba Ndlovu',
#        'Lindelwa Williams', 'Lwazi Mthembu', 'Tshepo Modise',
#        'Bongani Williams', 'Nokuthula Williams', 'Sipho Ndlovu',
#        'Kagiso Mkhize', 'Sibusiso Pillay', 'Karabo Botha',
#        'Tshepo Sithole', 'Zanele Modise', 'Mandla Naidoo', 'Lwazi Zulu',
#        'Zanele Mokoena', 'Nokuthula Sithole', 'Sibusiso Ngcobo',
#        'Ayanda Mokoena', 'Lerato Mahlangu', 'Lindelwa Dlamini',
#        'Themba Williams', 'Zanele Ndlovu', 'Lindelwa Van Wyk',
#        'Thabo Ndlovu', 'Mpho Mthembu', 'Karabo Sithole', 'Lerato Botha',
#        'Kabelo Nkosi', 'Kabelo Ndlovu', 'Lerato Nkosi', 'Mpho Zulu',
#        'Lwazi Adams', 'Busisiwe Williams', 'Karabo Mokoena',
#        'Zanele Pillay', 'Nokuthula Dlamini', 'Nokuthula Botha',
#        'Themba Moyo', 'Thabo Khumalo', 'Sibusiso Dlamini',
#        'Precious Botha', 'Themba Nkosi', 'Themba Dlamini',
#        'Amanda Molefe', 'Mpho Modise', 'Mandla Williams', 'Zanele Botha',
#        'Lindelwa Molefe', 'Thabo Zulu', 'Zanele Mabena', 'Tshepo Mthembu',
#        'Karabo Molefe', 'Nokuthula Cele', 'Kabelo Mkhize',
#        'Busisiwe Mkhize', 'Kabelo Jacobs', 'Nokuthula Adams',
#        'Karabo Dlamini', 'Sibusiso Moyo', 'Kagiso Molefe',
#        'Lindelwa Ngcobo', 'Sibusiso Adams', 'Lerato Mkhize',
#        'Precious Mabena', 'Dumisani Mkhize', 'Kabelo Molefe',
#        'Dumisani Pillay', 'Sibusiso Khumalo', 'Ayanda Naidoo',
#        'Sibusiso Sithole', 'Lerato Ngcobo', 'Lwazi Ndlovu', 'Lwazi Cele',
#        'Phumzile Williams', 'Lerato Mthembu', 'Lerato Adams',
#        'Zanele Jacobs', 'Mpho Adams', 'Thabo Modise', 'Nandi Botha',
#        'Ayanda Mkhize', 'Thabo Ngcobo', 'Themba Zulu', 'Bongani Mahlangu',
#        'Lwazi Dlamini', 'Kabelo Sithole', 'Themba Molefe',
#        'Lindelwa Moyo', 'Nomsa Mabena', 'Thabo Van Wyk',
#        'Dumisani Mahlangu', 'Lwazi Sithole', 'Dumisani Molefe',
#        'Busisiwe Mahlangu', 'Kabelo Naidoo', 'Zanele Van Wyk',
#        'Nomsa Jacobs', 'Nokuthula Ngcobo', 'Amanda Moyo',
#        'Siyabonga Dlamini', 'Phumzile Ngcobo', 'Bongani Mokoena',
#        'Mandla Mahlangu', 'Tshepo Mabena', 'Sibusiso Molefe',
#        'Siyabonga Modise', 'Sibusiso Naidoo', 'Nomsa Moyo',
#        'Siyabonga Jacobs', 'Busisiwe Ngcobo', 'Siyabonga Mabena',
#        'Lindelwa Ndlovu', 'Nomsa Botha', 'Kagiso Cele', 'Ayanda Zulu',
#        'Karabo Cele', 'Zanele Adams', 'Tshepo Pillay', 'Phumzile Mthembu',
#        'Lwazi Mokoena', 'Nandi Mthembu', 'Mpho Mkhize', 'Thabo Mokoena',
#        'Mpho Jacobs', 'Thabo Moyo', 'Sipho Molefe', 'Lindelwa Adams',
#        'Tshepo Moyo', 'Mpho Khumalo', 'Lerato Pillay', 'Kagiso Mthembu'],
#       dtype=object)

# %%
customers.customer_type.unique()
# Out:
# array(['Business', 'Individual', 'Enterprise'], dtype=object)

# %%
customers.province.unique()
# Out:
# array(['Gauteng', 'Limpopo', 'KwaZulu-Natal', 'Eastern Cape',
#        'Western Cape', 'North West', 'Free State', ' Western Cape ',
#        ' Gauteng ', 'Mpumalanga', 'Northern Cape', ' Eastern Cape ',
#        'gauteng', 'KWAZULU-NATAL', 'GAUTENG', 'western cape',
#        'EASTERN CAPE', 'MPUMALANGA', ' Limpopo ', ' KwaZulu-Natal ',
#        'eastern cape', 'kwazulu-natal', 'FREE STATE', 'north west',
#        'WESTERN CAPE', 'LIMPOPO', 'free state', ' Mpumalanga ', 'limpopo',
#        ' Free State ', 'NORTH WEST', 'NORTHERN CAPE', ' North West ',
#        'northern cape', 'mpumalanga', ' Northern Cape '], dtype=object)

# %%
#Fixing incosistence
customers.province= customers.province.str.strip()
customers.province= customers.province.str.title()
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\446329367.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers.province= customers.province.str.strip()
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\446329367.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers.province= customers.province.str.title()

# %%
customers.city.unique()
# Out:
# array(['Centurion', 'Johannesburg', 'Polokwane', 'Richards Bay',
#        'East London', 'Pretoria', 'Gqeberha', 'Umhlanga', 'Durban',
#        'Paarl', 'Newcastle', nan, 'Pietermaritzburg', 'Midrand',
#        'Grahamstown', 'Klerksdorp', 'Mthatha', 'Sandton', 'Cape Town',
#        'Soweto', 'Bloemfontein', 'Stellenbosch', 'Welkom', 'George',
#        'Bellville', 'Potchefstroom', 'Kroonstad', 'Worcester', 'Mahikeng',
#        'Tzaneen', 'Middelburg', 'Nelspruit', 'Kuruman', 'Mbombela',
#        'Thohoyandou', 'Witbank', 'Kimberley', 'Upington', 'Rustenburg'],
#       dtype=object)

# %%
customers.registration_date.unique()
# Out:
# <DatetimeArray>
# ['2024-10-13 00:00:00', '2022-01-26 00:00:00', '2019-03-04 00:00:00',
#  '2021-06-30 00:00:00', '2026-03-28 00:00:00', '2024-07-06 00:00:00',
#  '2018-09-30 00:00:00', '2024-04-16 00:00:00', '2025-02-19 00:00:00',
#  '2024-05-11 00:00:00',
#  ...
#  '2018-04-21 00:00:00', '2024-03-18 00:00:00', '2026-06-05 00:00:00',
#  '2022-03-30 00:00:00', '2019-08-03 00:00:00', '2019-04-29 00:00:00',
#  '2020-06-29 00:00:00', '2025-05-24 00:00:00', '2021-04-16 00:00:00',
#  '2023-05-26 00:00:00']
# Length: 3102, dtype: datetime64[ns]

# %%
customers.monthly_shipping_budget.unique()
# Out:
# array([ 3530.2 ,  1555.5 , 13767.67, ...,  9942.18,   838.25, 69674.92],
#       shape=(97684,))

# %%
customers['monthly_shipping_budget'].unique
# Out:
# <bound method Series.unique of 0         3530.20
# 1         1555.50
# 2        13767.67
# 3        10034.40
# 4         7054.38
#            ...
# 99995    78517.63
# 99996     7369.63
# 99997     9942.18
# 99998      838.25
# 99999    69674.92
# Name: monthly_shipping_budget, Length: 100000, dtype: float64>

# %%
#Checking for missing values
customers.isnull().sum()
# Out:
# customer_id                   0
# customer_name                 0
# customer_type                 0
# province                      0
# city                       1028
# registration_date             0
# monthly_shipping_budget     989
# dtype: int64

# %%
(customers.isna().sum() / len(customers)) * 100
# Out:
# customer_id                0.000
# customer_name              0.000
# customer_type              0.000
# province                   0.000
# city                       1.028
# registration_date          0.000
# monthly_shipping_budget    0.989
# dtype: float64

# %%
customers[customers['monthly_shipping_budget'].isna()]
# Out:
#       customer_id     customer_name customer_type       province  \
# 13        C000014       Amanda Cele    Individual        Limpopo
# 85        C000086    Lindelwa Nkosi    Individual  Kwazulu-Natal
# 202       C000203     Themba Mkhize      Business        Limpopo
# 236       C000237     Karabo Mabena      Business        Gauteng
# 263       C000264   Phumzile Naidoo      Business        Gauteng
# ...           ...               ...           ...            ...
# 98827     C098828       Ayanda Zulu    Enterprise     Free State
# 98997     C098998  Siyabonga Pillay      Business   Eastern Cape
# 99405     C099406    Kagiso Mokoena    Individual   Western Cape
# 99540     C099541     Mandla Ngcobo    Individual  Kwazulu-Natal
# 99787     C099788   Precious Jacobs      Business  Kwazulu-Natal
#
#                city registration_date  monthly_shipping_budget
# 13        Polokwane        2024-02-01                      NaN
# 85        Newcastle        2024-11-13                      NaN
# 202     Thohoyandou        2025-01-10                      NaN
# 236       Centurion        2019-07-28                      NaN
# 263    Johannesburg        2018-07-21                      NaN
# ...             ...               ...                      ...
# 98827     Kroonstad        2020-07-09                      NaN
# 98997      Gqeberha        2021-12-10                      NaN
# 99405         Paarl        2019-01-18                      NaN
# 99540      Umhlanga        2022-02-20                      NaN
# 99787        Durban        2022-01-04                      NaN
#
# [989 rows x 7 columns]

# %%
customers['monthly_shipping_budget'].isna().sum()
# Out:
# np.int64(989)

# %%
customers[customers['city'].isna()]["city"]
# Out:
# 14       NaN
# 160      NaN
# 251      NaN
# 290      NaN
# 328      NaN
#         ...
# 99526    NaN
# 99577    NaN
# 99603    NaN
# 99830    NaN
# 99841    NaN
# Name: city, Length: 1028, dtype: object

# %%
customers['city'].isna().sum()
# Out:
# np.int64(1028)

# %%
#Checking the Pronvices in which province has cities that has missing value 
customers.loc[customers['city'].isna(), "province"].value_counts()
# Out:
# province
# Gauteng          301
# Kwazulu-Natal    208
# Western Cape     189
# Eastern Cape     106
# Free State        60
# Limpopo           56
# Mpumalanga        54
# North West        36
# Northern Cape     18
# Name: count, dtype: int64

# %%
customers['city'] = customers['city'].fillna('Unknown')
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\4010663513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['city'] = customers['city'].fillna('Unknown')

# %%
customers.loc[customers['monthly_shipping_budget'].isna(), "city"].value_counts()
# Out:
# city
# Johannesburg        56
# Sandton             49
# Centurion           46
# Midrand             44
# Richards Bay        43
# Soweto              42
# Pietermaritzburg    42
# Mthatha             38
# Pretoria            37
# Bellville           36
# Gqeberha            33
# George              32
# Newcastle           31
# Stellenbosch        29
# Bloemfontein        29
# Paarl               29
# Umhlanga            29
# Worcester           29
# Durban              27
# Polokwane           26
# Cape Town           25
# Thohoyandou         22
# Tzaneen             21
# Kroonstad           21
# Grahamstown         20
# Nelspruit           16
# East London         16
# Welkom              14
# Witbank             14
# Klerksdorp          12
# Rustenburg          12
# Unknown             11
# Mbombela            11
# Potchefstroom        9
# Mahikeng             9
# Middelburg           8
# Kuruman              8
# Upington             7
# Kimberley            6
# Name: count, dtype: int64

# %%
customers['monthly_shipping_budget'] = customers['monthly_shipping_budget'].fillna(
customers['monthly_shipping_budget'].median())
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\3097473623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['monthly_shipping_budget'] = customers['monthly_shipping_budget'].fillna(

# %%
customers.groupby("city")["monthly_shipping_budget"].median()
# Out:
# city
# Bellville           14747.090
# Bloemfontein        14514.720
# Cape Town           14944.890
# Centurion           15164.880
# Durban              15059.575
# East London         15326.425
# George              14573.205
# Gqeberha            14944.890
# Grahamstown         15170.260
# Johannesburg        14944.890
# Kimberley           14579.660
# Klerksdorp          13989.130
# Kroonstad           15485.175
# Kuruman             14693.720
# Mahikeng            15193.880
# Mbombela            14409.735
# Middelburg          14944.890
# Midrand             14944.890
# Mthatha             14779.860
# Nelspruit           14998.120
# Newcastle           15136.870
# Paarl               15087.915
# Pietermaritzburg    14944.890
# Polokwane           15612.720
# Potchefstroom       14423.190
# Pretoria            14944.890
# Richards Bay        14555.900
# Rustenburg          14902.880
# Sandton             15180.260
# Soweto              14944.890
# Stellenbosch        14944.890
# Thohoyandou         14712.870
# Tzaneen             14944.890
# Umhlanga            14974.320
# Unknown             14922.705
# Upington            13498.205
# Welkom              15290.850
# Witbank             14222.310
# Worcester           14944.595
# Name: monthly_shipping_budget, dtype: float64

# %%
city_counts = customers.groupby(["province", "city"]).size().reset_index(name= "Customer_count")
city_counts
# Out:
#          province              city  Customer_count
# 0    Eastern Cape       East London            2478
# 1    Eastern Cape          Gqeberha            2408
# 2    Eastern Cape       Grahamstown            2605
# 3    Eastern Cape           Mthatha            2462
# 4    Eastern Cape           Unknown             106
# 5      Free State      Bloemfontein            2020
# 6      Free State         Kroonstad            1980
# 7      Free State           Unknown              60
# 8      Free State            Welkom            2035
# 9         Gauteng         Centurion            5073
# 10        Gauteng      Johannesburg            5050
# 11        Gauteng           Midrand            4817
# 12        Gauteng          Pretoria            4842
# 13        Gauteng           Sandton            4755
# 14        Gauteng            Soweto            5029
# 15        Gauteng           Unknown             301
# 16  Kwazulu-Natal            Durban            3530
# 17  Kwazulu-Natal         Newcastle            3511
# 18  Kwazulu-Natal  Pietermaritzburg            3499
# 19  Kwazulu-Natal      Richards Bay            3600
# 20  Kwazulu-Natal          Umhlanga            3657
# 21  Kwazulu-Natal           Unknown             208
# 22        Limpopo         Polokwane            2318
# 23        Limpopo       Thohoyandou            2323
# 24        Limpopo           Tzaneen            2339
# 25        Limpopo           Unknown              56
# 26     Mpumalanga          Mbombela            1274
# 27     Mpumalanga        Middelburg            1201
# 28     Mpumalanga         Nelspruit            1259
# 29     Mpumalanga           Unknown              54
# 30     Mpumalanga           Witbank            1241
# 31     North West        Klerksdorp             947
# 32     North West          Mahikeng            1025
# 33     North West     Potchefstroom             953
# 34     North West        Rustenburg             994
# 35     North West           Unknown              36
# 36  Northern Cape         Kimberley             644
# 37  Northern Cape           Kuruman             630
# 38  Northern Cape           Unknown              18
# 39  Northern Cape          Upington             666
# 40   Western Cape         Bellville            2967
# 41   Western Cape         Cape Town            3052
# 42   Western Cape            George            3064
# 43   Western Cape             Paarl            2898
# 44   Western Cape      Stellenbosch            2944
# 45   Western Cape           Unknown             189
# 46   Western Cape         Worcester            2882

# %% [markdown]
# # Insepecting Shipments and Cleaning

# %%
import pandas as pd
shipments = pd.read_csv("supplyguard_data/shipments.csv")
shipments
# Out:
#         shipment_id customer_id warehouse_id shipment_date shipment_type  \
# 0        S000000001     C063536       W00238    2025-12-14       Express
# 1        S000000002     C054654       W00230    2025-03-21       Express
# 2        S000000003     C075489       W00180    2026-06-23          Bulk
# 3        S000000004     C041283       W00029    2026-07-21      Same Day
# 4        S000000005     C019038       W00013    2025-07-15       Express
# ...             ...         ...          ...           ...           ...
# 1002995  S000387159     C079142       W00026    2025-03-12      Standard
# 1002996  S000211228     C058421       W00055    2025-02-01          Bulk
# 1002997  S000229470     C042115       W00046    2025-11-04      Standard
# 1002998  S000003812     C037869       W00115    2026-04-05      Standard
# 1002999  S000786818     C089289       W00224    2025-05-06      Standard
#
#         delivery_method  weight_kg declared_value_zar  distance_km  priority
# 0                  Road      11.97           10832.99       926.17       Low
# 1                  Road      73.29           90025.97        63.22    Medium
# 2                  Road      90.70           73339.17       374.86  Critical
# 3                   Air      13.26           11410.73       148.44    Medium
# 4                  Road      36.98           23529.59        61.17       Low
# ...                 ...        ...                ...          ...       ...
# 1002995            Road      11.18           13327.15       363.99    Medium
# 1002996            Road       2.09             882.78       234.72       Low
# 1002997            Road      44.40            9095.88        17.82    Medium
# 1002998            Road      34.45           51389.76       330.49    Medium
# 1002999         Freight      13.09            8404.28       494.27    Medium
#
# [1003000 rows x 10 columns]

# %%
shipments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003000 entries, 0 to 1002999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   shipment_id         1003000 non-null  object
#  1   customer_id         1003000 non-null  object
#  2   warehouse_id        1003000 non-null  object
#  3   shipment_date       1003000 non-null  object
#  4   shipment_type       1003000 non-null  object
#  5   delivery_method     1003000 non-null  object
#  6   weight_kg           1003000 non-null  float64
#  7   declared_value_zar  992909 non-null   object
#  8   distance_km         992910 non-null   float64
#  9   priority            1003000 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 76.5+ MB

# %%
shipments.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1002995     True
# 1002996     True
# 1002997     True
# 1002998     True
# 1002999     True
# Length: 1003000, dtype: bool

# %%
shipments[shipments.duplicated() == True]
# Out:
#         shipment_id customer_id warehouse_id shipment_date shipment_type  \
# 1000000  S000910392     C010270       W00225    2025-08-29      Standard
# 1000001  S000521922     C042237       W00212    2026-04-21      Standard
# 1000002  S000085994     C051034       W00140    2025-11-01       Express
# 1000003  S000316326     C007728       W00218    2025-05-13      Standard
# 1000004  S000374572     C049758       W00042    2025-02-14       Express
# ...             ...         ...          ...           ...           ...
# 1002995  S000387159     C079142       W00026    2025-03-12      Standard
# 1002996  S000211228     C058421       W00055    2025-02-01          Bulk
# 1002997  S000229470     C042115       W00046    2025-11-04      Standard
# 1002998  S000003812     C037869       W00115    2026-04-05      Standard
# 1002999  S000786818     C089289       W00224    2025-05-06      Standard
#
#         delivery_method  weight_kg declared_value_zar  distance_km priority
# 1000000            Road      29.49            36820.7       171.15   Medium
# 1000001            Road       2.91             157.86       115.51   Medium
# 1000002            Road      86.49          109568.46        84.32     High
# 1000003         Courier      11.68            9564.37        13.86   Medium
# 1000004            Road     290.74           50297.92      1856.51   Medium
# ...                 ...        ...                ...          ...      ...
# 1002995            Road      11.18           13327.15       363.99   Medium
# 1002996            Road       2.09             882.78       234.72      Low
# 1002997            Road      44.40            9095.88        17.82   Medium
# 1002998            Road      34.45           51389.76       330.49   Medium
# 1002999         Freight      13.09            8404.28       494.27   Medium
#
# [3000 rows x 10 columns]

# %%
shipments = shipments.drop_duplicates()

# %%
shipments['shipment_date'] = pd.to_datetime(shipments['shipment_date'])
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\3395169456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['shipment_date'] = pd.to_datetime(shipments['shipment_date'])

# %%
shipments['declared_value_zar'] = shipments['declared_value_zar'].str.replace(",", "")
shipments['declared_value_zar'] = shipments['declared_value_zar'].str.replace(" ", "")
shipments['declared_value_zar'] = shipments['declared_value_zar'].astype(float)
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\1826243068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['declared_value_zar'] = shipments['declared_value_zar'].str.replace(",", "")
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\1826243068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['declared_value_zar'] = shipments['declared_value_zar'].str.replace(" ", "")
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\1826243068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['declared_value_zar'] = shipments['declared_value_zar'].astype(float)

# %%
shipments.columns
# Out:
# Index(['shipment_id', 'customer_id', 'warehouse_id', 'shipment_date',
#        'shipment_type', 'delivery_method', 'weight_kg', 'declared_value_zar',
#        'distance_km', 'priority'],
#       dtype='object')

# %%
shipments.shipment_type.unique()
# Out:
# array(['Express', 'Bulk', 'Same Day', 'Standard', 'International'],
#       dtype=object)

# %%
shipments.delivery_method.unique()
# Out:
# array(['Road', 'Air', 'Freight', 'Courier'], dtype=object)

# %%
shipments.weight_kg.unique()
# Out:
# array([ 11.97,  73.29,  90.7 , ..., 165.71, 365.76, 396.94],
#       shape=(37612,))

# %%
shipments.declared_value_zar.unique()
# Out:
# array([10832.99, 90025.97, 73339.17, ...,  9506.09, 14523.73, 11580.34],
#       shape=(876828,))

# %%
shipments.distance_km.unique()
# Out:
# array([ 926.17,   63.22,  374.86, ..., 2348.77, 2092.64, 1583.85],
#       shape=(150660,))

# %%
shipments.priority.unique()
# Out:
# array(['Low', 'Medium', 'Critical', 'High', 'MEDIUM', 'medium', 'high',
#        'LOW', 'HIGH', ' Medium ', ' Low ', 'critical', ' High ',
#        'CRITICAL', 'low', ' Critical '], dtype=object)

# %%
shipments.priority= shipments.priority.str.strip()
shipments.priority= shipments.priority.str.title()
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\113188996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments.priority= shipments.priority.str.strip()
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\113188996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments.priority= shipments.priority.str.title()

# %%
shipments.isna().sum()
# Out:
# shipment_id               0
# customer_id               0
# warehouse_id              0
# shipment_date             0
# shipment_type             0
# delivery_method           0
# weight_kg                 0
# declared_value_zar    10062
# distance_km           10064
# priority                  0
# dtype: int64

# %%
(shipments.isna().sum() / len(shipments)) * 100
# Out:
# shipment_id           0.0000
# customer_id           0.0000
# warehouse_id          0.0000
# shipment_date         0.0000
# shipment_type         0.0000
# delivery_method       0.0000
# weight_kg             0.0000
# declared_value_zar    1.0062
# distance_km           1.0064
# priority              0.0000
# dtype: float64

# %%
shipments[['declared_value_zar', 'distance_km']].isna().mean() * 100
# Out:
# declared_value_zar    1.0062
# distance_km           1.0064
# dtype: float64

# %%
shipments.loc[shipments['declared_value_zar'].isna(), "shipment_type"].value_counts()
# Out:
# shipment_type
# Standard         5005
# Express          2009
# Bulk             1479
# Same Day         1065
# International     504
# Name: count, dtype: int64

# %%
shipments['declared_value_zar'].isna().sum()
# Out:
# np.int64(10062)

# %%
shipments[shipments['declared_value_zar'].isna()]['declared_value_zar']
# Out:
# 34       NaN
# 562      NaN
# 785      NaN
# 954      NaN
# 1071     NaN
#           ..
# 999614   NaN
# 999630   NaN
# 999671   NaN
# 999744   NaN
# 999875   NaN
# Name: declared_value_zar, Length: 10062, dtype: float64

# %%
shipments['declared_value_zar'] = shipments['declared_value_zar'].fillna(
shipments['declared_value_zar'].median())
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\885146159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['declared_value_zar'] = shipments['declared_value_zar'].fillna(

# %%
shipments.loc[shipments['distance_km'].isna(), "priority"].value_counts()
# Out:
# priority
# Medium      4987
# High        2546
# Low         2010
# Critical     521
# Name: count, dtype: int64

# %%
shipments[shipments['distance_km'].isna()]['distance_km']
# Out:
# 9        NaN
# 161      NaN
# 340      NaN
# 546      NaN
# 624      NaN
#           ..
# 999503   NaN
# 999614   NaN
# 999761   NaN
# 999851   NaN
# 999927   NaN
# Name: distance_km, Length: 10064, dtype: float64

# %%
shipments.loc[shipments['declared_value_zar'].isna(), "distance_km"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
shipments['distance_km'] = shipments['distance_km'].fillna(
shipments['distance_km'].median())
# Out:
# C:\Users\E1023380\AppData\Local\Temp\ipykernel_30760\1370765055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shipments['distance_km'] = shipments['distance_km'].fillna(

# %% [markdown]
# # Inspecting  Vehicle and Cleaning data

# %%
import pandas as pd
vehicles = pd.read_csv("supplyguard_data/vehicles.csv")
vehicles
# Out:
#       vehicle_id  vehicle_type  vehicle_age_years  capacity_kg fuel_type  \
# 0        V000001  Medium Truck                  1         8000    Diesel
# 1        V000002  Medium Truck                  5         8000    Diesel
# 2        V000003  Medium Truck                  5         8000    Diesel
# 3        V000004     Motorbike                 11           50    Petrol
# 4        V000005           Van                  4         1000    Petrol
# ...          ...           ...                ...          ...       ...
# 14995    V014996  Medium Truck                  2         8000    Diesel
# 14996    V014997  Medium Truck                  6         8000    Diesel
# 14997    V014998  Medium Truck                 12         8000    Diesel
# 14998    V014999  Medium Truck                 14         8000    Diesel
# 14999    V015000   Light Truck                 12         3500    Diesel
#
#        maintenance_score  current_mileage_km
# 0                  85.06            193997.0
# 1                  83.39             72050.0
# 2                  68.78              1000.0
# 3                  66.61            206076.0
# 4                  89.17            119600.0
# ...                  ...                 ...
# 14995              90.91            245536.0
# 14996             100.00            201289.0
# 14997              77.80             91515.0
# 14998              73.72            105680.0
# 14999              75.55            155478.0
#
# [15000 rows x 7 columns]

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vehicle_id          15000 non-null  object
#  1   vehicle_type        15000 non-null  object
#  2   vehicle_age_years   15000 non-null  int64
#  3   capacity_kg         15000 non-null  int64
#  4   fuel_type           15000 non-null  object
#  5   maintenance_score   15000 non-null  float64
#  6   current_mileage_km  15000 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 820.4+ KB

# %%
vehicles.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# 14999    False
# Length: 15000, dtype: bool

# %%
vehicles[vehicles.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [vehicle_id, vehicle_type, vehicle_age_years, capacity_kg, fuel_type, maintenance_score, current_mileage_km]
# Index: []

# %%
vehicles.columns
# Out:
# Index(['vehicle_id', 'vehicle_type', 'vehicle_age_years', 'capacity_kg',
#        'fuel_type', 'maintenance_score', 'current_mileage_km'],
#       dtype='object')

# %%
vehicles.vehicle_type.unique()
# Out:
# array(['Medium Truck', 'Motorbike', 'Van', 'Light Truck', 'Heavy Truck'],
#       dtype=object)

# %%
vehicles.vehicle_age_years.unique()
# Out:
# array([ 1,  5, 11,  4,  0,  7,  6, 14,  9, 10, 12, 13,  8,  3,  2])

# %%
vehicles.capacity_kg.unique()
# Out:
# array([ 8000,    50,  1000,  3500, 20000])

# %%
vehicles.fuel_type.unique()
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
vehicles.maintenance_score.unique()
# Out:
# array([85.06, 83.39, 68.78, ..., 61.34, 61.1 , 59.42], shape=(4117,))

# %%
vehicles.current_mileage_km.unique()
# Out:
# array([193997.,  72050.,   1000., ...,  91515., 105680., 155478.],
#       shape=(14298,))

# %%
print(vehicles["current_mileage_km"].head(10).to_list())
# Out:
# [193997.0, 72050.0, 1000.0, 206076.0, 119600.0, 163284.0, 154709.0, 23537.0, 337431.0, 172167.0]

# %%
vehicles.isna().sum()
# Out:
# vehicle_id            0
# vehicle_type          0
# vehicle_age_years     0
# capacity_kg           0
# fuel_type             0
# maintenance_score     0
# current_mileage_km    0
# dtype: int64

# %% [markdown]
# # Insepecting exchange rate and cleaning data

# %%
import pandas as pd
exchange_rates = pd.read_csv("supplyguard_data/exchange_rates.csv")
exchange_rates
# Out:
#             date currency  zar_rate
# 0     2025-01-01      USD   18.1591
# 1     2025-01-01      GBP   23.2890
# 2     2025-01-01      EUR   21.0701
# 3     2025-01-01      AUD   11.7025
# 4     2025-01-02      USD   18.3837
# ...          ...      ...       ...
# 2303  2026-07-30      AUD   11.8109
# 2304  2026-07-31      USD   18.4465
# 2305  2026-07-31      GBP   23.5821
# 2306  2026-07-31      EUR   20.8384
# 2307  2026-07-31      AUD   11.9483
#
# [2308 rows x 3 columns]

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2308 entries, 0 to 2307
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2308 non-null   object
#  1   currency  2308 non-null   object
#  2   zar_rate  2308 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 54.2+ KB

# %%
exchange_rates.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2303    False
# 2304    False
# 2305    False
# 2306    False
# 2307    False
# Length: 2308, dtype: bool

# %%
exchange_rates[exchange_rates.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [date, currency, zar_rate]
# Index: []

# %%
exchange_rates.columns
# Out:
# Index(['date', 'currency', 'zar_rate'], dtype='object')

# %%
exchange_rates.date.unique()
# Out:
# array(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#        '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#        '2025-01-09', '2025-01-10', '2025-01-11', '2025-01-12',
#        '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#        '2025-01-17', '2025-01-18', '2025-01-19', '2025-01-20',
#        '2025-01-21', '2025-01-22', '2025-01-23', '2025-01-24',
#        '2025-01-25', '2025-01-26', '2025-01-27', '2025-01-28',
#        '2025-01-29', '2025-01-30', '2025-01-31', '2025-02-01',
#        '2025-02-02', '2025-02-03', '2025-02-04', '2025-02-05',
#        '2025-02-06', '2025-02-07', '2025-02-08', '2025-02-09',
#        '2025-02-10', '2025-02-11', '2025-02-12', '2025-02-13',
#        '2025-02-14', '2025-02-15', '2025-02-16', '2025-02-17',
#        '2025-02-18', '2025-02-19', '2025-02-20', '2025-02-21',
#        '2025-02-22', '2025-02-23', '2025-02-24', '2025-02-25',
#        '2025-02-26', '2025-02-27', '2025-02-28', '2025-03-01',
#        '2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#        '2025-03-06', '2025-03-07', '2025-03-08', '2025-03-09',
#        '2025-03-10', '2025-03-11', '2025-03-12', '2025-03-13',
#        '2025-03-14', '2025-03-15', '2025-03-16', '2025-03-17',
#        '2025-03-18', '2025-03-19', '2025-03-20', '2025-03-21',
#        '2025-03-22', '2025-03-23', '2025-03-24', '2025-03-25',
#        '2025-03-26', '2025-03-27', '2025-03-28', '2025-03-29',
#        '2025-03-30', '2025-03-31', '2025-04-01', '2025-04-02',
#        '2025-04-03', '2025-04-04', '2025-04-05', '2025-04-06',
#        '2025-04-07', '2025-04-08', '2025-04-09', '2025-04-10',
#        '2025-04-11', '2025-04-12', '2025-04-13', '2025-04-14',
#        '2025-04-15', '2025-04-16', '2025-04-17', '2025-04-18',
#        '2025-04-19', '2025-04-20', '2025-04-21', '2025-04-22',
#        '2025-04-23', '2025-04-24', '2025-04-25', '2025-04-26',
#        '2025-04-27', '2025-04-28', '2025-04-29', '2025-04-30',
#        '2025-05-01', '2025-05-02', '2025-05-03', '2025-05-04',
#        '2025-05-05', '2025-05-06', '2025-05-07', '2025-05-08',
#        '2025-05-09', '2025-05-10', '2025-05-11', '2025-05-12',
#        '2025-05-13', '2025-05-14', '2025-05-15', '2025-05-16',
#        '2025-05-17', '2025-05-18', '2025-05-19', '2025-05-20',
#        '2025-05-21', '2025-05-22', '2025-05-23', '2025-05-24',
#        '2025-05-25', '2025-05-26', '2025-05-27', '2025-05-28',
#        '2025-05-29', '2025-05-30', '2025-05-31', '2025-06-01',
#        '2025-06-02', '2025-06-03', '2025-06-04', '2025-06-05',
#        '2025-06-06', '2025-06-07', '2025-06-08', '2025-06-09',
#        '2025-06-10', '2025-06-11', '2025-06-12', '2025-06-13',
#        '2025-06-14', '2025-06-15', '2025-06-16', '2025-06-17',
#        '2025-06-18', '2025-06-19', '2025-06-20', '2025-06-21',
#        '2025-06-22', '2025-06-23', '2025-06-24', '2025-06-25',
#        '2025-06-26', '2025-06-27', '2025-06-28', '2025-06-29',
#        '2025-06-30', '2025-07-01', '2025-07-02', '2025-07-03',
#        '2025-07-04', '2025-07-05', '2025-07-06', '2025-07-07',
#        '2025-07-08', '2025-07-09', '2025-07-10', '2025-07-11',
#        '2025-07-12', '2025-07-13', '2025-07-14', '2025-07-15',
#        '2025-07-16', '2025-07-17', '2025-07-18', '2025-07-19',
#        '2025-07-20', '2025-07-21', '2025-07-22', '2025-07-23',
#        '2025-07-24', '2025-07-25', '2025-07-26', '2025-07-27',
#        '2025-07-28', '2025-07-29', '2025-07-30', '2025-07-31',
#        '2025-08-01', '2025-08-02', '2025-08-03', '2025-08-04',
#        '2025-08-05', '2025-08-06', '2025-08-07', '2025-08-08',
#        '2025-08-09', '2025-08-10', '2025-08-11', '2025-08-12',
#        '2025-08-13', '2025-08-14', '2025-08-15', '2025-08-16',
#        '2025-08-17', '2025-08-18', '2025-08-19', '2025-08-20',
#        '2025-08-21', '2025-08-22', '2025-08-23', '2025-08-24',
#        '2025-08-25', '2025-08-26', '2025-08-27', '2025-08-28',
#        '2025-08-29', '2025-08-30', '2025-08-31', '2025-09-01',
#        '2025-09-02', '2025-09-03', '2025-09-04', '2025-09-05',
#        '2025-09-06', '2025-09-07', '2025-09-08', '2025-09-09',
#        '2025-09-10', '2025-09-11', '2025-09-12', '2025-09-13',
#        '2025-09-14', '2025-09-15', '2025-09-16', '2025-09-17',
#        '2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21',
#        '2025-09-22', '2025-09-23', '2025-09-24', '2025-09-25',
#        '2025-09-26', '2025-09-27', '2025-09-28', '2025-09-29',
#        '2025-09-30', '2025-10-01', '2025-10-02', '2025-10-03',
#        '2025-10-04', '2025-10-05', '2025-10-06', '2025-10-07',
#        '2025-10-08', '2025-10-09', '2025-10-10', '2025-10-11',
#        '2025-10-12', '2025-10-13', '2025-10-14', '2025-10-15',
#        '2025-10-16', '2025-10-17', '2025-10-18', '2025-10-19',
#        '2025-10-20', '2025-10-21', '2025-10-22', '2025-10-23',
#        '2025-10-24', '2025-10-25', '2025-10-26', '2025-10-27',
#        '2025-10-28', '2025-10-29', '2025-10-30', '2025-10-31',
#        '2025-11-01', '2025-11-02', '2025-11-03', '2025-11-04',
#        '2025-11-05', '2025-11-06', '2025-11-07', '2025-11-08',
#        '2025-11-09', '2025-11-10', '2025-11-11', '2025-11-12',
#        '2025-11-13', '2025-11-14', '2025-11-15', '2025-11-16',
#        '2025-11-17', '2025-11-18', '2025-11-19', '2025-11-20',
#        '2025-11-21', '2025-11-22', '2025-11-23', '2025-11-24',
#        '2025-11-25', '2025-11-26', '2025-11-27', '2025-11-28',
#        '2025-11-29', '2025-11-30', '2025-12-01', '2025-12-02',
#        '2025-12-03', '2025-12-04', '2025-12-05', '2025-12-06',
#        '2025-12-07', '2025-12-08', '2025-12-09', '2025-12-10',
#        '2025-12-11', '2025-12-12', '2025-12-13', '2025-12-14',
#        '2025-12-15', '2025-12-16', '2025-12-17', '2025-12-18',
#        '2025-12-19', '2025-12-20', '2025-12-21', '2025-12-22',
#        '2025-12-23', '2025-12-24', '2025-12-25', '2025-12-26',
#        '2025-12-27', '2025-12-28', '2025-12-29', '2025-12-30',
#        '2025-12-31', '2026-01-01', '2026-01-02', '2026-01-03',
#        '2026-01-04', '2026-01-05', '2026-01-06', '2026-01-07',
#        '2026-01-08', '2026-01-09', '2026-01-10', '2026-01-11',
#        '2026-01-12', '2026-01-13', '2026-01-14', '2026-01-15',
#        '2026-01-16', '2026-01-17', '2026-01-18', '2026-01-19',
#        '2026-01-20', '2026-01-21', '2026-01-22', '2026-01-23',
#        '2026-01-24', '2026-01-25', '2026-01-26', '2026-01-27',
#        '2026-01-28', '2026-01-29', '2026-01-30', '2026-01-31',
#        '2026-02-01', '2026-02-02', '2026-02-03', '2026-02-04',
#        '2026-02-05', '2026-02-06', '2026-02-07', '2026-02-08',
#        '2026-02-09', '2026-02-10', '2026-02-11', '2026-02-12',
#        '2026-02-13', '2026-02-14', '2026-02-15', '2026-02-16',
#        '2026-02-17', '2026-02-18', '2026-02-19', '2026-02-20',
#        '2026-02-21', '2026-02-22', '2026-02-23', '2026-02-24',
#        '2026-02-25', '2026-02-26', '2026-02-27', '2026-02-28',
#        '2026-03-01', '2026-03-02', '2026-03-03', '2026-03-04',
#        '2026-03-05', '2026-03-06', '2026-03-07', '2026-03-08',
#        '2026-03-09', '2026-03-10', '2026-03-11', '2026-03-12',
#        '2026-03-13', '2026-03-14', '2026-03-15', '2026-03-16',
#        '2026-03-17', '2026-03-18', '2026-03-19', '2026-03-20',
#        '2026-03-21', '2026-03-22', '2026-03-23', '2026-03-24',
#        '2026-03-25', '2026-03-26', '2026-03-27', '2026-03-28',
#        '2026-03-29', '2026-03-30', '2026-03-31', '2026-04-01',
#        '2026-04-02', '2026-04-03', '2026-04-04', '2026-04-05',
#        '2026-04-06', '2026-04-07', '2026-04-08', '2026-04-09',
#        '2026-04-10', '2026-04-11', '2026-04-12', '2026-04-13',
#        '2026-04-14', '2026-04-15', '2026-04-16', '2026-04-17',
#        '2026-04-18', '2026-04-19', '2026-04-20', '2026-04-21',
#        '2026-04-22', '2026-04-23', '2026-04-24', '2026-04-25',
#        '2026-04-26', '2026-04-27', '2026-04-28', '2026-04-29',
#        '2026-04-30', '2026-05-01', '2026-05-02', '2026-05-03',
#        '2026-05-04', '2026-05-05', '2026-05-06', '2026-05-07',
#        '2026-05-08', '2026-05-09', '2026-05-10', '2026-05-11',
#        '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15',
#        '2026-05-16', '2026-05-17', '2026-05-18', '2026-05-19',
#        '2026-05-20', '2026-05-21', '2026-05-22', '2026-05-23',
#        '2026-05-24', '2026-05-25', '2026-05-26', '2026-05-27',
#        '2026-05-28', '2026-05-29', '2026-05-30', '2026-05-31',
#        '2026-06-01', '2026-06-02', '2026-06-03', '2026-06-04',
#        '2026-06-05', '2026-06-06', '2026-06-07', '2026-06-08',
#        '2026-06-09', '2026-06-10', '2026-06-11', '2026-06-12',
#        '2026-06-13', '2026-06-14', '2026-06-15', '2026-06-16',
#        '2026-06-17', '2026-06-18', '2026-06-19', '2026-06-20',
#        '2026-06-21', '2026-06-22', '2026-06-23', '2026-06-24',
#        '2026-06-25', '2026-06-26', '2026-06-27', '2026-06-28',
#        '2026-06-29', '2026-06-30', '2026-07-01', '2026-07-02',
#        '2026-07-03', '2026-07-04', '2026-07-05', '2026-07-06',
#        '2026-07-07', '2026-07-08', '2026-07-09', '2026-07-10',
#        '2026-07-11', '2026-07-12', '2026-07-13', '2026-07-14',
#        '2026-07-15', '2026-07-16', '2026-07-17', '2026-07-18',
#        '2026-07-19', '2026-07-20', '2026-07-21', '2026-07-22',
#        '2026-07-23', '2026-07-24', '2026-07-25', '2026-07-26',
#        '2026-07-27', '2026-07-28', '2026-07-29', '2026-07-30',
#        '2026-07-31'], dtype=object)

# %%
exchange_rates['date'] = pd.to_datetime(exchange_rates['date'])

# %%
exchange_rates.currency.unique()
# Out:
# array(['USD', 'GBP', 'EUR', 'AUD'], dtype=object)

# %%
exchange_rates['zar_rate'] = pd.to_numeric(exchange_rates['zar_rate'])

# %%
exchange_rates.isna().sum()
# Out:
# date        0
# currency    0
# zar_rate    0
# dtype: int64

# %% [markdown]
# # Inspecting Deliveries and Cleaning data

# %%
import pandas as pd
deliveries = pd.read_csv("supplyguard_data/deliveries.csv")
deliveries
# Out:
#         delivery_id shipment_id driver_id vehicle_id delivery_date  \
# 0       DL000000001  S000000001   D002400    V013743    2025-12-16
# 1       DL000000002  S000000002   D006019    V012835    2025-03-22
# 2       DL000000003  S000000003   D006461    V000347    2026-06-26
# 3       DL000000004  S000000004   D007914    V010330    2026-07-21
# 4       DL000000005  S000000005   D005693    V011795    2025-07-16
# ...             ...         ...       ...        ...           ...
# 999995  DL000999996  S000999996   D005627    V000427    2025-07-08
# 999996  DL000999997  S000999997   D001882    V006763    2026-05-05
# 999997  DL000999998  S000999998   D008550    V010821    2025-12-17
# 999998  DL000999999  S000999999   D008389    V004063    2026-03-04
# 999999  DL001000000  S001000000   D005538    V011867    2025-05-31
#
#        delivery_status  delivery_duration_hours  delivery_distance_km  \
# 0       Delivered Late                    16.60                935.04
# 1            Delivered                     1.06                 57.08
# 2            Delivered                     7.56                402.48
# 3            Delivered                     3.35                147.70
# 4            Delivered                     1.81                 54.77
# ...                ...                      ...                   ...
# 999995       Delivered                     1.33                 64.93
# 999996       Delivered                     3.63                261.61
# 999997       Delivered                     2.01                100.67
# 999998       Delivered                     1.17                 58.36
# 999999       Delivered                     4.37                217.80
#
#         fuel_cost_zar  customer_rating  attempt_number  delivery_hour
# 0             2504.92             2.30               3              9
# 1              115.77             3.30               1             12
# 2              891.87             4.09               1             19
# 3              609.51             3.68               1             16
# 4              122.58             4.18               1             17
# ...               ...              ...             ...            ...
# 999995         202.73             4.04               1              6
# 999996         946.81             4.29               2             16
# 999997         371.75             4.38               1             13
# 999998         157.25             4.64               1              5
# 999999         695.03             4.57               1             17
#
# [1000000 rows x 12 columns]

# %%
deliveries.info()

# %%
deliveries.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
deliveries[deliveries.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [delivery_id, shipment_id, driver_id, vehicle_id, delivery_date, delivery_status, delivery_duration_hours, delivery_distance_km, fuel_cost_zar, customer_rating, attempt_number, delivery_hour]
# Index: []

# %%
deliveries.columns
# Out:
# Index(['delivery_id', 'shipment_id', 'driver_id', 'vehicle_id',
#        'delivery_date', 'delivery_status', 'delivery_duration_hours',
#        'delivery_distance_km', 'fuel_cost_zar', 'customer_rating',
#        'attempt_number', 'delivery_hour'],
#       dtype='object')

# %%
deliveries.delivery_date.unique()
# Out:
# array(['2025-12-16', '2025-03-22', '2026-06-26', '2026-07-21',
#        '2025-07-16', '2026-04-29', '2025-12-10', '2025-07-17',
#        '2025-05-11', '2026-03-13', '2026-03-24', '2026-07-08',
#        '2025-09-24', '2026-07-28', '2026-03-27', '2026-07-15',
#        '2026-04-14', '2025-01-23', '2026-03-29', '2025-12-20',
#        '2025-06-14', '2026-01-09', '2025-04-01', '2026-03-14',
#        '2025-08-24', '2026-02-03', '2026-05-02', '2025-01-03',
#        '2025-12-26', '2025-03-20', '2026-05-10', '2026-03-22',
#        '2025-09-02', '2026-03-26', '2025-10-05', '2025-03-10',
#        '2026-03-18', '2025-03-25', '2026-05-20', '2026-05-19',
#        '2025-03-24', '2025-01-28', '2026-03-06', '2025-01-05',
#        '2025-01-07', '2026-04-11', '2026-04-21', '2026-04-27',
#        '2025-10-06', '2025-04-12', '2026-02-05', '2025-11-06',
#        '2026-04-06', '2025-07-08', '2026-03-11', '2025-11-11',
#        '2026-01-17', '2025-04-16', '2025-10-07', '2025-07-28',
#        '2026-08-01', '2026-04-22', '2025-12-29', '2025-01-13',
#        '2025-05-01', '2025-09-28', '2026-05-25', '2026-07-24',
#        '2026-06-05', '2025-09-17', '2025-07-29', '2025-08-30',
#        '2025-04-28', '2026-01-05', '2026-03-15', '2026-04-17',
#        '2025-02-24', '2025-07-12', '2026-01-12', '2026-01-29',
#        '2025-01-18', '2026-01-04', '2025-08-06', '2026-02-21',
#        '2025-07-07', '2025-01-04', '2025-08-22', '2026-03-04',
#        '2026-02-28', '2025-10-31', '2026-05-18', '2025-11-02',
#        '2025-04-13', '2025-10-09', '2025-01-12', '2026-01-30',
#        '2025-01-26', '2025-10-29', '2025-06-28', '2025-11-29',
#        '2026-02-11', '2026-05-30', '2025-03-11', '2025-04-24',
#        '2026-03-03', '2026-01-19', '2026-07-27', '2025-01-11',
#        '2025-02-25', '2025-01-19', '2026-06-15', '2026-06-22',
#        '2025-09-12', '2025-04-25', '2026-01-14', '2026-07-22',
#        '2026-06-09', '2026-06-01', '2025-04-10', '2026-05-29',
#        '2026-05-31', '2025-09-25', '2026-05-01', '2025-07-26',
#        '2025-01-02', '2025-11-16', '2025-07-31', '2025-10-24',
#        '2026-01-20', '2025-07-10', '2025-05-22', '2025-04-04',
#        '2025-07-03', '2025-10-02', '2026-05-28', '2025-09-23',
#        '2025-03-29', '2025-01-30', '2025-02-13', '2025-06-18',
#        '2025-08-01', '2025-07-30', '2026-02-25', '2025-08-10',
#        '2026-06-17', '2026-06-29', '2025-11-07', '2025-01-15',
#        '2026-07-04', '2025-01-06', '2025-05-04', '2026-01-18',
#        '2026-05-06', '2025-11-12', '2025-10-19', '2025-06-07',
#        '2026-05-03', '2025-12-05', '2026-07-14', '2025-10-08',
#        '2025-03-07', '2026-04-07', '2025-11-27', '2025-09-08',
#        '2025-08-04', '2026-01-13', '2025-04-08', '2026-05-12',
#        '2025-09-11', '2025-04-07', '2025-02-08', '2026-01-24',
#        '2025-03-15', '2025-08-26', '2025-12-22', '2025-06-11',
#        '2026-06-19', '2025-07-04', '2025-08-15', '2025-02-18',
#        '2025-04-06', '2026-03-19', '2025-07-20', '2026-04-16',
#        '2026-02-26', '2026-03-21', '2025-01-27', '2025-02-21',
#        '2026-06-21', '2026-02-10', '2025-06-25', '2026-05-09',
#        '2026-07-26', '2025-07-22', '2025-06-13', '2025-01-17',
#        '2025-11-24', '2026-04-30', '2026-06-16', '2025-02-01',
#        '2026-06-27', '2026-06-10', '2026-07-23', '2025-03-01',
#        '2025-05-03', '2026-03-17', '2025-02-09', '2025-05-24',
#        '2026-07-10', '2025-02-17', '2026-05-27', '2025-02-22',
#        '2026-07-29', '2026-03-08', '2026-07-25', '2026-06-13',
#        '2025-04-21', '2025-08-29', '2025-01-29', '2025-07-19',
#        '2025-05-08', '2026-04-05', '2025-03-28', '2025-10-21',
#        '2025-05-07', '2025-05-06', '2026-04-20', '2026-02-23',
#        '2026-02-19', '2025-11-05', '2026-03-23', '2025-10-13',
#        '2025-04-23', '2026-06-24', '2025-11-04', '2026-07-31',
#        '2026-04-04', '2025-09-13', '2025-09-29', '2025-01-10',
#        '2025-08-12', '2025-05-31', '2025-12-14', '2025-07-18',
#        '2025-02-10', '2026-05-23', '2025-09-16', '2025-10-25',
#        '2025-12-03', '2025-09-01', '2025-09-06', '2026-04-23',
#        '2026-06-30', '2025-12-12', '2025-06-17', '2025-10-15',
#        '2026-01-25', '2025-08-31', '2025-03-02', '2025-07-01',
#        '2026-07-18', '2025-08-03', '2026-03-12', '2025-02-27',
#        '2025-12-30', '2026-01-28', '2026-04-08', '2025-05-21',
#        '2026-02-17', '2026-04-19', '2025-03-30', '2026-05-15',
#        '2025-05-30', '2026-02-02', '2025-05-25', '2026-06-02',
#        '2025-10-04', '2025-03-18', '2025-10-22', '2025-11-15',
#        '2026-07-07', '2025-08-09', '2025-06-16', '2025-11-30',
#        '2026-08-04', '2025-10-11', '2025-05-29', '2026-07-19',
#        '2026-01-21', '2025-01-25', '2025-09-30', '2026-01-26',
#        '2025-11-22', '2026-04-10', '2025-10-01', '2025-06-05',
#        '2026-01-16', '2025-04-20', '2025-03-23', '2025-05-19',
#        '2026-05-04', '2026-03-02', '2026-05-22', '2025-03-08',
#        '2025-12-01', '2025-12-17', '2025-05-28', '2025-10-30',
#        '2025-01-22', '2025-01-08', '2025-03-03', '2025-07-02',
#        '2025-04-11', '2026-05-21', '2025-03-06', '2025-09-07',
#        '2025-09-03', '2025-09-27', '2026-02-12', '2025-09-14',
#        '2025-06-02', '2025-12-15', '2025-04-29', '2026-01-10',
#        '2025-05-27', '2025-07-15', '2025-11-14', '2025-06-27',
#        '2026-04-25', '2025-11-01', '2025-08-28', '2025-11-23',
#        '2025-03-31', '2025-06-24', '2025-04-22', '2026-02-20',
#        '2026-02-13', '2025-05-20', '2025-07-06', '2025-02-04',
#        '2025-11-28', '2025-04-15', '2026-04-18', '2025-12-11',
#        '2025-10-17', '2025-07-14', '2026-04-15', '2026-02-09',
#        '2025-12-13', '2025-08-21', '2026-01-22', '2026-03-01',
#        '2025-02-23', '2025-10-28', '2025-12-06', '2025-12-02',
#        '2025-05-16', '2026-06-03', '2026-03-09', '2025-12-25',
#        '2025-11-10', '2026-06-28', '2026-04-28', '2025-07-25',
#        '2025-02-20', '2025-04-26', '2025-02-12', '2025-08-18',
#        '2025-10-20', '2025-06-12', '2026-05-11', '2026-07-12',
#        '2026-05-08', '2025-02-15', '2025-03-13', '2025-01-14',
#        '2025-05-26', '2025-09-18', '2026-04-12', '2026-07-06',
#        '2026-01-06', '2025-03-19', '2025-09-26', '2025-04-14',
#        '2025-02-05', '2026-02-27', '2026-06-25', '2025-01-16',
#        '2025-06-08', '2026-06-08', '2025-09-19', '2025-05-02',
#        '2026-07-30', '2025-10-10', '2025-03-27', '2026-05-05',
#        '2026-04-02', '2025-04-18', '2025-07-11', '2026-03-10',
#        '2025-08-17', '2026-05-26', '2026-07-20', '2025-04-02',
#        '2025-03-05', '2025-11-21', '2025-04-27', '2025-07-24',
#        '2025-01-21', '2026-06-07', '2025-04-30', '2025-02-26',
#        '2025-08-19', '2025-01-31', '2025-10-03', '2026-01-08',
#        '2026-04-26', '2026-05-24', '2026-06-23', '2025-06-22',
#        '2025-06-29', '2025-05-13', '2025-06-20', '2026-08-02',
#        '2025-11-19', '2026-06-14', '2025-03-09', '2025-12-21',
#        '2025-07-23', '2025-10-26', '2025-02-03', '2025-08-14',
#        '2025-08-16', '2026-06-11', '2026-07-17', '2025-09-15',
#        '2025-11-20', '2025-03-17', '2026-05-16', '2025-05-15',
#        '2026-06-18', '2026-03-16', '2026-07-03', '2026-07-02',
#        '2025-04-09', '2025-04-05', '2026-03-20', '2025-12-27',
#        '2025-02-28', '2025-10-12', '2026-01-11', '2025-09-10',
#        '2025-12-28', '2025-12-18', '2026-04-03', '2025-12-07',
#        '2026-03-28', '2025-08-05', '2025-07-05', '2025-07-13',
#        '2025-06-19', '2026-03-25', '2025-08-25', '2026-05-17',
#        '2025-06-04', '2025-05-18', '2025-02-11', '2025-11-03',
#        '2026-01-15', '2025-01-09', '2025-09-04', '2026-02-15',
#        '2025-08-02', '2026-02-18', '2026-01-03', '2025-11-17',
#        '2025-02-07', '2025-08-07', '2025-12-08', '2025-06-10',
#        '2026-02-16', '2025-07-21', '2026-04-24', '2025-11-09',
#        '2026-02-07', '2025-12-23', '2025-03-21', '2026-05-07',
#        '2025-05-10', '2026-07-01', '2025-09-22', '2025-10-14',
#        '2026-07-16', '2025-08-23', '2025-12-04', '2025-09-21',
#        '2025-03-04', '2025-12-19', '2026-02-14', '2025-11-26',
#        '2025-01-24', '2025-11-13', '2026-04-01', '2025-06-21',
#        '2026-02-06', '2025-08-13', '2025-02-16', '2025-04-03',
#        '2025-11-25', '2025-07-09', '2025-03-26', '2026-02-24',
#        '2025-12-09', '2025-03-16', '2026-07-09', '2026-07-11',
#        '2026-03-07', '2025-06-09', '2025-03-12', '2026-05-13',
#        '2025-04-19', '2026-01-31', '2025-06-06', '2025-09-09',
#        '2026-04-09', '2025-04-17', '2025-06-26', '2025-01-20',
#        '2025-09-20', '2025-10-23', '2025-08-27', '2025-05-23',
#        '2026-06-06', '2025-11-18', '2025-12-24', '2026-02-01',
#        '2025-03-14', '2025-10-16', '2025-05-09', '2025-07-27',
#        '2026-07-05', '2026-02-08', '2025-05-14', '2025-02-19',
#        '2026-03-30', '2026-01-01', '2025-05-12', '2026-01-27',
#        '2025-02-02', '2025-02-06', '2025-02-14', '2026-06-12',
#        '2025-05-17', '2026-01-07', '2026-06-04', '2025-06-03',
#        '2025-09-05', '2026-06-20', '2025-08-11', '2026-03-31',
#        '2025-08-08', '2026-02-04', '2025-06-15', '2026-05-14',
#        '2026-04-13', '2025-05-05', '2025-06-30', '2026-01-02',
#        '2025-06-23', '2025-10-27', '2025-10-18', '2026-01-23',
#        '2025-08-20', '2026-03-05', '2025-12-31', '2026-07-13',
#        '2025-06-01', '2026-02-22', '2026-08-03', '2025-11-08',
#        '2025-01-01', '2026-08-05', '2026-08-08', '2026-08-07',
#        '2026-08-06'], dtype=object)

# %%
deliveries['delivery_date'] = pd.to_datetime(deliveries['delivery_date'])

# %%
deliveries.delivery_status.unique()
# Out:
# array(['Delivered Late', 'Delivered', 'Delayed', 'DELIVERED', 'delayed',
#        'delivered', 'delivered late', ' Delivered ', ' Delivered Late ',
#        'DELIVERED LATE', ' Delayed ', 'DELAYED'], dtype=object)

# %%
deliveries.delivery_status= deliveries.delivery_status.str.strip()
deliveries.delivery_status= deliveries.delivery_status.str.title()

# %%
deliveries.delivery_duration_hours.unique()
# Out:
# array([16.6 ,  1.06,  7.56, ..., 41.67, 63.06, 61.21], shape=(6451,))

# %%
deliveries.delivery_distance_km.unique()
# Out:
# array([ 935.04,   57.08,  402.48, ..., 1737.04, 1762.13, 2167.17],
#       shape=(162063,))

# %%
deliveries.fuel_cost_zar.unique()
# Out:
# array([2504.92,  115.77,  891.87, ..., 2315.06, 1270.61, 2509.55],
#       shape=(332709,))

# %%
deliveries.customer_rating.unique()
# Out:
# array([2.3 , 3.3 , 4.09, 3.68, 4.18, 3.52, 4.  , 2.84, 4.72, 3.99, 4.06,
#        4.47, 4.62, 3.75, 4.75, 4.12, 2.56, 3.91, 5.  , 4.66, 3.73, 4.98,
#        4.25, 1.62, 3.92, 4.78, 4.71, 3.97, 1.  , 3.15, 4.17, 3.93, 4.85,
#        4.32, 4.39, 2.94, 4.22, 4.73, 4.13, 4.86, 3.54, 4.69, 1.48, 3.16,
#        2.02, 3.72, 3.38, 2.91, 3.86, 1.86, 3.74, 4.95, 4.16, 3.13, 3.37,
#        4.02, 2.25, 4.03, 3.49, 1.88, 4.8 , 2.68, 3.64, 4.64, 4.23, 3.35,
#        4.5 , 4.55, 4.59, 3.79, 3.89, 4.11, 4.76, 4.94, 3.51, 4.37,  nan,
#        4.56, 3.98, 4.24, 4.48, 3.1 , 4.68, 3.48, 4.19, 4.6 , 4.57, 4.27,
#        4.49, 3.53, 3.94, 2.41, 4.2 , 4.21, 4.42, 2.55, 3.58, 4.87, 4.65,
#        3.67, 4.28, 3.95, 2.85, 4.33, 4.97, 4.99, 4.04, 3.25, 2.18, 1.76,
#        3.85, 3.29, 3.77, 3.23, 1.65, 4.29, 4.4 , 3.87, 4.79, 4.51, 4.26,
#        3.84, 3.07, 4.41, 3.96, 3.88, 1.16, 2.64, 3.69, 3.21, 2.75, 3.76,
#        2.28, 4.77, 4.31, 4.35, 2.59, 3.63, 4.08, 1.2 , 3.9 , 2.66, 3.8 ,
#        3.06, 3.6 , 4.89, 4.38, 3.  , 2.52, 4.14, 2.7 , 2.96, 4.3 , 2.46,
#        2.21, 3.11, 4.46, 2.12, 4.01, 3.4 , 4.05, 3.55, 4.74, 2.1 , 4.07,
#        3.71, 2.99, 4.54, 1.9 , 3.14, 4.67, 2.77, 3.7 , 4.93, 4.43, 3.82,
#        4.52, 4.36, 2.79, 3.19, 3.17, 3.5 , 3.46, 4.82, 3.09, 1.78, 3.66,
#        4.7 , 3.47, 4.63, 4.96, 3.59, 2.15, 4.45, 4.84, 1.95, 1.81, 4.44,
#        4.58, 2.88, 1.74, 3.83, 4.15, 3.81, 2.97, 4.92, 3.57, 3.34, 3.65,
#        2.72, 1.93, 2.22, 4.9 , 3.22, 4.53, 3.31, 4.61, 3.28, 3.78, 2.67,
#        4.34, 3.61, 4.88, 2.37, 2.93, 4.83, 3.33, 2.86, 3.04, 3.56, 2.32,
#        1.7 , 1.84, 3.62, 3.26, 3.02, 1.41, 2.23, 2.  , 1.92, 2.57, 3.18,
#        2.71, 1.25, 2.62, 2.06, 3.41, 3.44, 1.27, 4.81, 3.42, 3.32, 2.51,
#        3.05, 2.04, 2.53, 2.13, 2.95, 2.76, 1.11, 1.73, 3.24, 1.46, 2.48,
#        1.58, 4.1 , 3.2 , 2.87, 2.9 , 2.01, 1.96, 1.8 , 1.43, 1.37, 4.91,
#        1.69, 3.39, 2.65, 2.54, 1.36, 3.03, 2.35, 3.45, 3.12, 2.11, 1.97,
#        2.4 , 2.8 , 2.5 , 1.87, 2.44, 1.3 , 2.14, 2.2 , 2.83, 2.09, 3.01,
#        3.08, 3.27, 2.58, 2.74, 2.6 , 2.92, 3.36, 2.78, 2.24, 1.94, 2.69,
#        2.89, 1.07, 1.63, 2.81, 2.43, 2.49, 1.28, 1.44, 2.47, 2.45, 2.16,
#        1.53, 1.59, 2.39, 2.05, 1.47, 1.39, 2.26, 1.91, 1.26, 1.89, 3.43,
#        1.42, 2.19, 2.42, 1.29, 1.56, 1.68, 1.06, 1.67, 1.55, 1.75, 2.08,
#        2.36, 1.99, 1.66, 2.29, 2.17, 2.33, 2.73, 1.31, 1.5 , 2.82, 1.1 ,
#        1.49, 2.63, 1.34, 1.32, 1.61, 1.33, 1.72, 1.54, 1.35, 1.45, 2.98,
#        2.61, 1.79, 2.31, 1.98, 1.22, 1.51, 2.27, 1.38, 2.07, 1.71, 1.4 ,
#        1.85, 2.34, 1.77, 1.08, 1.52, 1.83, 1.82, 2.38, 1.64, 1.21, 1.12,
#        1.6 , 1.14, 1.09, 1.13, 1.01, 1.02, 2.03, 1.23, 1.15, 1.18, 1.03,
#        1.05, 1.57, 1.04, 1.24, 1.17, 1.19])

# %%
deliveries.attempt_number.unique()
# Out:
# array([3, 1, 2])

# %%
deliveries.delivery_hour.unique()
# Out:
# array([ 9, 12, 19, 16, 17, 18, 14, 20, 13, 21, 10,  6,  5,  8, 15, 22, 11,
#         7])

# %%
deliveries.isnull().sum()
# Out:
# delivery_id                   0
# shipment_id                   0
# driver_id                     0
# vehicle_id                    0
# delivery_date                 0
# delivery_status               0
# delivery_duration_hours       0
# delivery_distance_km          0
# fuel_cost_zar              9869
# customer_rating            9984
# attempt_number                0
# delivery_hour                 0
# dtype: int64

# %%
deliveries.groupby("delivery_status")["fuel_cost_zar"].median()

# %%
deliveries["fuel_cost_zar"] = deliveries["fuel_cost_zar"].fillna(
deliveries.groupby("delivery_status")["fuel_cost_zar"].transform("median"))

# %%
deliveries["fuel_cost_zar"].isna().sum()
# Out:
# np.int64(0)

# %%
deliveries["fuel_cost_zar"] = deliveries["fuel_cost_zar"].fillna(deliveries["fuel_cost_zar"].median())

# %%
deliveries["customer_rating"].describe()
deliveries["customer_rating"].value_counts().sort_index()

# %%
deliveries["customer_rating"] = deliveries["customer_rating"].fillna(deliveries["customer_rating"].median())

# %% [markdown]
# # Inspecting Drivers and Cleaning Data

# %%
import pandas as pd
drivers = pd.read_csv("supplyguard_data/drivers.csv")
drivers
# Out:
#      driver_id       driver_name  age  experience_years license_type  \
# 0      D000001   Dumisani Molefe   47                34      Code 10
# 1      D000002       Mpho Modise   59                25      Code 10
# 2      D000003     Themba Naidoo   37                 6      Code 14
# 3      D000004    Tshepo Dlamini   38                23       Code 8
# 4      D000005  Nokuthula Ndlovu   50                 3       Code 8
# ...        ...               ...  ...               ...          ...
# 9995   D009996   Lindelwa Naidoo   49                 8      Code 14
# 9996   D009997     Nandi Sithole   58                32      Code 14
# 9997   D009998      Kabelo Adams   47                 8      Code 10
# 9998   D009999   Amanda Mahlangu   37                23      Code 14
# 9999   D010000  Sibusiso Mthembu   25                 2       Code 8
#
#      employment_type  home_province  performance_rating
# 0           Contract     North West                3.51
# 1           Contract   Western Cape                3.28
# 2          Permanent     Free State                4.59
# 3           Contract   Western Cape                4.31
# 4       Owner Driver     Mpumalanga                3.80
# ...              ...            ...                 ...
# 9995       Permanent  Northern Cape                4.18
# 9996        Contract  KwaZulu-Natal                5.00
# 9997       Permanent        Gauteng                4.43
# 9998        Contract  KwaZulu-Natal                4.37
# 9999       Permanent        Limpopo                4.45
#
# [10000 rows x 8 columns]

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   driver_id           10000 non-null  object
#  1   driver_name         10000 non-null  object
#  2   age                 10000 non-null  int64
#  3   experience_years    10000 non-null  int64
#  4   license_type        10000 non-null  object
#  5   employment_type     10000 non-null  object
#  6   home_province       10000 non-null  object
#  7   performance_rating  10000 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 625.1+ KB

# %%
drivers.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
drivers[drivers.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [driver_id, driver_name, age, experience_years, license_type, employment_type, home_province, performance_rating]
# Index: []

# %%
drivers.columns
# Out:
# Index(['driver_id', 'driver_name', 'age', 'experience_years', 'license_type',
#        'employment_type', 'home_province', 'performance_rating'],
#       dtype='object')

# %%
drivers.driver_name.unique()
# Out:
# array(['Dumisani Molefe', 'Mpho Modise', 'Themba Naidoo',
#        'Tshepo Dlamini', 'Nokuthula Ndlovu', 'Lerato Moyo',
#        'Siyabonga Khumalo', 'Lwazi Botha', 'Thabo Mthembu',
#        'Zanele Jacobs', 'Siyabonga Naidoo', 'Themba Mokoena',
#        'Sipho Naidoo', 'Lerato Mkhize', 'Sibusiso Dlamini',
#        'Lindelwa Botha', 'Kabelo Modise', 'Phumzile Naidoo',
#        'Lerato Mabena', 'Karabo Modise', 'Busisiwe Modise',
#        'Thabo Williams', 'Sibusiso Jacobs', 'Precious Nkosi',
#        'Precious Mthembu', 'Nokuthula Nkosi', 'Amanda Botha',
#        'Nomsa Molefe', 'Dumisani Jacobs', 'Sipho Adams', 'Lwazi Moyo',
#        'Nokuthula Dlamini', 'Bongani Mkhize', 'Lindelwa Pillay',
#        'Mpho Naidoo', 'Kagiso Maseko', 'Lwazi Mokoena', 'Mpho Sithole',
#        'Sipho Zulu', 'Siyabonga Moyo', 'Phumzile Mkhize',
#        'Sibusiso Botha', 'Nokuthula Naidoo', 'Lindelwa Dlamini',
#        'Lwazi Maseko', 'Zanele Modise', 'Mandla Jacobs', 'Karabo Mthembu',
#        'Zanele Mahlangu', 'Mandla Mahlangu', 'Sipho Mokoena',
#        'Mandla Khumalo', 'Precious Jacobs', 'Bongani Mabena',
#        'Siyabonga Cele', 'Themba Sithole', 'Precious Mabena',
#        'Nandi Modise', 'Zanele Pillay', 'Mandla Pillay', 'Tshepo Zulu',
#        'Tshepo Modise', 'Kabelo Nkosi', 'Precious Khumalo', 'Kagiso Zulu',
#        'Mandla Ndlovu', 'Zanele Ndlovu', 'Lwazi Modise',
#        'Dumisani Modise', 'Ayanda Adams', 'Kabelo Adams', 'Lwazi Khumalo',
#        'Nomsa Jacobs', 'Lerato Dlamini', 'Nomsa Moyo', 'Kagiso Mkhize',
#        'Precious Williams', 'Tshepo Mokoena', 'Lindelwa Williams',
#        'Mpho Pillay', 'Thabo Maseko', 'Bongani Mokoena', 'Nomsa Adams',
#        'Sibusiso Adams', 'Lindelwa Ngcobo', 'Mandla Van Wyk',
#        'Nomsa Zulu', 'Lindelwa Modise', 'Sibusiso Williams',
#        'Busisiwe Ndlovu', 'Karabo Ndlovu', 'Mpho Mabena',
#        'Ayanda Khumalo', 'Lwazi Jacobs', 'Sibusiso Van Wyk',
#        'Themba Mabena', 'Themba Moyo', 'Busisiwe Mthembu',
#        'Kagiso Dlamini', 'Phumzile Modise', 'Kabelo Mahlangu',
#        'Amanda Mabena', 'Nokuthula Moyo', 'Thabo Khumalo',
#        'Nandi Mahlangu', 'Karabo Khumalo', 'Amanda Mkhize', 'Lwazi Nkosi',
#        'Ayanda Moyo', 'Nokuthula Mkhize', 'Zanele Cele', 'Nomsa Maseko',
#        'Tshepo Nkosi', 'Precious Botha', 'Mpho Mthembu', 'Nomsa Khumalo',
#        'Karabo Mahlangu', 'Mandla Moyo', 'Mandla Mkhize',
#        'Siyabonga Nkosi', 'Mandla Sithole', 'Phumzile Ngcobo',
#        'Karabo Naidoo', 'Themba Williams', 'Busisiwe Mahlangu',
#        'Kabelo Mthembu', 'Karabo Adams', 'Sipho Mabena',
#        'Ayanda Williams', 'Phumzile Pillay', 'Dumisani Botha',
#        'Lindelwa Zulu', 'Sipho Ngcobo', 'Amanda Maseko', 'Themba Cele',
#        'Kagiso Jacobs', 'Busisiwe Mokoena', 'Kagiso Mabena',
#        'Bongani Ngcobo', 'Sibusiso Sithole', 'Sibusiso Ndlovu',
#        'Siyabonga Mabena', 'Karabo Mabena', 'Amanda Dlamini',
#        'Ayanda Sithole', 'Mandla Dlamini', 'Themba Adams', 'Nandi Ngcobo',
#        'Zanele Van Wyk', 'Mpho Mahlangu', 'Precious Pillay', 'Mpho Nkosi',
#        'Precious Cele', 'Zanele Khumalo', 'Dumisani Adams',
#        'Lerato Naidoo', 'Ayanda Van Wyk', 'Themba Mthembu',
#        'Sibusiso Molefe', 'Sibusiso Moyo', 'Mandla Molefe',
#        'Kagiso Ngcobo', 'Lindelwa Van Wyk', 'Thabo Mabena',
#        'Kabelo Molefe', 'Zanele Moyo', 'Thabo Zulu', 'Dumisani Mahlangu',
#        'Nokuthula Ngcobo', 'Sipho Williams', 'Amanda Mahlangu',
#        'Sipho Maseko', 'Lindelwa Nkosi', 'Themba Ngcobo',
#        'Zanele Sithole', 'Thabo Molefe', 'Nokuthula Botha',
#        'Nandi Ndlovu', 'Mpho Mkhize', 'Lwazi Zulu', 'Mandla Zulu',
#        'Mpho Ngcobo', 'Lindelwa Mabena', 'Amanda Jacobs',
#        'Kagiso Williams', 'Siyabonga Adams', 'Mpho Williams',
#        'Nomsa Ndlovu', 'Themba Molefe', 'Nokuthula Cele', 'Amanda Adams',
#        'Precious Modise', 'Sipho Mthembu', 'Ayanda Modise',
#        'Phumzile Jacobs', 'Tshepo Khumalo', 'Kabelo Mokoena',
#        'Karabo Molefe', 'Lindelwa Mokoena', 'Ayanda Pillay',
#        'Mpho Maseko', 'Tshepo Adams', 'Thabo Mkhize', 'Sipho Nkosi',
#        'Mpho Cele', 'Dumisani Williams', 'Nomsa Nkosi', 'Lindelwa Molefe',
#        'Kabelo Cele', 'Tshepo Ndlovu', 'Amanda Molefe', 'Lerato Williams',
#        'Nomsa Sithole', 'Nomsa Botha', 'Dumisani Moyo', 'Themba Ndlovu',
#        'Zanele Ngcobo', 'Nandi Mabena', 'Amanda Nkosi',
#        'Phumzile Khumalo', 'Tshepo Van Wyk', 'Mpho Mokoena',
#        'Kabelo Van Wyk', 'Themba Pillay', 'Tshepo Naidoo', 'Mpho Jacobs',
#        'Precious Maseko', 'Kagiso Mahlangu', 'Sibusiso Nkosi',
#        'Ayanda Botha', 'Lindelwa Jacobs', 'Thabo Naidoo',
#        'Nokuthula Maseko', 'Themba Jacobs', 'Mandla Maseko',
#        'Busisiwe Maseko', 'Kabelo Jacobs', 'Lwazi Ndlovu',
#        'Bongani Van Wyk', 'Phumzile Williams', 'Lerato Sithole',
#        'Kagiso Mthembu', 'Busisiwe Mkhize', 'Karabo Dlamini',
#        'Siyabonga Dlamini', 'Mpho Ndlovu', 'Phumzile Mokoena',
#        'Mpho Molefe', 'Sibusiso Naidoo', 'Zanele Zulu', 'Mandla Ngcobo',
#        'Siyabonga Jacobs', 'Lindelwa Moyo', 'Mandla Mabena',
#        'Phumzile Mabena', 'Siyabonga Modise', 'Thabo Cele',
#        'Bongani Nkosi', 'Tshepo Williams', 'Sibusiso Ngcobo',
#        'Nandi Cele', 'Lindelwa Mahlangu', 'Nandi Williams', 'Thabo Adams',
#        'Themba Khumalo', 'Bongani Ndlovu', 'Kagiso Naidoo',
#        'Nokuthula Khumalo', 'Precious Mkhize', 'Dumisani Ndlovu',
#        'Lindelwa Maseko', 'Busisiwe Mabena', 'Sipho Modise',
#        'Kabelo Naidoo', 'Busisiwe Jacobs', 'Lindelwa Sithole',
#        'Bongani Maseko', 'Lerato Nkosi', 'Lindelwa Ndlovu',
#        'Ayanda Mabena', 'Phumzile Moyo', 'Nokuthula Zulu',
#        'Tshepo Jacobs', 'Sibusiso Mkhize', 'Phumzile Botha',
#        'Busisiwe Moyo', 'Nandi Zulu', 'Sipho Molefe', 'Sipho Ndlovu',
#        'Siyabonga Ndlovu', 'Nandi Botha', 'Sipho Dlamini',
#        'Lerato Ndlovu', 'Busisiwe Dlamini', 'Precious Dlamini',
#        'Themba Zulu', 'Tshepo Maseko', 'Sipho Mahlangu', 'Mandla Cele',
#        'Sibusiso Zulu', 'Siyabonga Molefe', 'Tshepo Mabena',
#        'Themba Botha', 'Kagiso Adams', 'Siyabonga Van Wyk',
#        'Phumzile Sithole', 'Ayanda Mthembu', 'Phumzile Mahlangu',
#        'Sipho Moyo', 'Siyabonga Mokoena', 'Nokuthula Mthembu',
#        'Nandi Dlamini', 'Bongani Dlamini', 'Zanele Molefe',
#        'Mandla Mokoena', 'Busisiwe Botha', 'Bongani Khumalo',
#        'Mpho Dlamini', 'Karabo Jacobs', 'Themba Mkhize', 'Zanele Adams',
#        'Themba Modise', 'Sipho Jacobs', 'Kabelo Moyo', 'Lindelwa Mkhize',
#        'Dumisani Mabena', 'Busisiwe Van Wyk', 'Amanda Cele',
#        'Zanele Williams', 'Kabelo Ngcobo', 'Busisiwe Khumalo',
#        'Thabo Ngcobo', 'Amanda Ndlovu', 'Amanda Moyo', 'Nandi Molefe',
#        'Siyabonga Mahlangu', 'Tshepo Mkhize', 'Kagiso Nkosi',
#        'Amanda Mokoena', 'Zanele Nkosi', 'Nandi Mokoena', 'Tshepo Cele',
#        'Bongani Molefe', 'Kagiso Moyo', 'Busisiwe Nkosi',
#        'Busisiwe Williams', 'Ayanda Cele', 'Dumisani Nkosi',
#        'Bongani Mahlangu', 'Tshepo Botha', 'Lerato Mokoena',
#        'Lwazi Naidoo', 'Nokuthula Molefe', 'Phumzile Molefe',
#        'Precious Naidoo', 'Zanele Botha', 'Kagiso Modise', 'Lerato Botha',
#        'Amanda Ngcobo', 'Amanda Sithole', 'Ayanda Mokoena',
#        'Lindelwa Cele', 'Lerato Van Wyk', 'Nokuthula Mokoena',
#        'Bongani Cele', 'Karabo Ngcobo', 'Zanele Mabena',
#        'Nokuthula Williams', 'Nandi Moyo', 'Sibusiso Cele',
#        'Karabo Mkhize', 'Kabelo Zulu', 'Sibusiso Khumalo',
#        'Sibusiso Modise', 'Karabo Williams', 'Mpho Adams', 'Ayanda Zulu',
#        'Precious Ndlovu', 'Dumisani Maseko', 'Dumisani Naidoo',
#        'Kagiso Cele', 'Mpho Moyo', 'Zanele Mkhize', 'Lwazi Dlamini',
#        'Lerato Ngcobo', 'Siyabonga Mthembu', 'Nomsa Dlamini',
#        'Lindelwa Mthembu', 'Dumisani Zulu', 'Kabelo Williams',
#        'Kabelo Ndlovu', 'Dumisani Van Wyk', 'Nokuthula Jacobs',
#        'Bongani Zulu', 'Karabo Pillay', 'Amanda Van Wyk', 'Kabelo Pillay',
#        'Kagiso Sithole', 'Phumzile Dlamini', 'Kabelo Sithole',
#        'Dumisani Mthembu', 'Siyabonga Sithole', 'Amanda Mthembu',
#        'Kabelo Maseko', 'Kabelo Mkhize', 'Mpho Zulu', 'Lerato Jacobs',
#        'Thabo Botha', 'Nandi Naidoo', 'Kagiso Khumalo', 'Nomsa Mahlangu',
#        'Lerato Cele', 'Siyabonga Williams', 'Nandi Sithole',
#        'Bongani Naidoo', 'Tshepo Moyo', 'Nokuthula Pillay',
#        'Tshepo Pillay', 'Bongani Pillay', 'Lerato Molefe', 'Nandi Adams',
#        'Lwazi Mthembu', 'Ayanda Mahlangu', 'Nomsa Van Wyk',
#        'Precious Zulu', 'Thabo Pillay', 'Themba Mahlangu', 'Karabo Nkosi',
#        'Precious Mahlangu', 'Siyabonga Ngcobo', 'Nomsa Mokoena',
#        'Lindelwa Khumalo', 'Kabelo Botha', 'Nokuthula Sithole',
#        'Mandla Naidoo', 'Nomsa Naidoo', 'Nomsa Modise', 'Sipho Van Wyk',
#        'Mandla Nkosi', 'Zanele Mthembu', 'Phumzile Adams',
#        'Lwazi Mahlangu', 'Phumzile Van Wyk', 'Amanda Modise',
#        'Nandi Jacobs', 'Nokuthula Van Wyk', 'Kagiso Ndlovu',
#        'Themba Dlamini', 'Lindelwa Adams', 'Thabo Jacobs',
#        'Karabo Mokoena', 'Sipho Cele', 'Thabo Sithole', 'Lerato Maseko',
#        'Thabo Mahlangu', 'Nandi Pillay', 'Dumisani Mkhize',
#        'Thabo Dlamini', 'Busisiwe Ngcobo', 'Karabo Sithole',
#        'Sipho Pillay', 'Nandi Khumalo', 'Zanele Dlamini', 'Mandla Modise',
#        'Kagiso Pillay', 'Phumzile Zulu', 'Amanda Naidoo', 'Karabo Botha',
#        'Amanda Pillay', 'Lwazi Pillay', 'Tshepo Mthembu', 'Mpho Botha',
#        'Dumisani Mokoena', 'Thabo Modise', 'Lwazi Mkhize',
#        'Sibusiso Mabena', 'Nandi Maseko', 'Bongani Mthembu',
#        'Kagiso Mokoena', 'Siyabonga Pillay', 'Phumzile Mthembu',
#        'Dumisani Khumalo', 'Mpho Khumalo', 'Themba Van Wyk',
#        'Sibusiso Pillay', 'Nokuthula Mabena', 'Nomsa Mabena',
#        'Nandi Mkhize', 'Lerato Pillay', 'Thabo Ndlovu', 'Zanele Mokoena',
#        'Tshepo Molefe', 'Precious Ngcobo', 'Kagiso Molefe',
#        'Sibusiso Maseko', 'Amanda Khumalo', 'Precious Moyo',
#        'Karabo Maseko', 'Bongani Williams', 'Dumisani Sithole',
#        'Lindelwa Naidoo', 'Dumisani Cele', 'Busisiwe Adams',
#        'Sibusiso Mahlangu', 'Lwazi Ngcobo', 'Ayanda Naidoo',
#        'Kagiso Botha', 'Nokuthula Mahlangu', 'Nomsa Mthembu',
#        'Kabelo Dlamini', 'Busisiwe Molefe', 'Precious Adams',
#        'Bongani Adams', 'Nokuthula Modise', 'Phumzile Cele',
#        'Karabo Moyo', 'Lwazi Williams', 'Ayanda Nkosi', 'Kabelo Khumalo',
#        'Sibusiso Mokoena', 'Themba Nkosi', 'Dumisani Dlamini',
#        'Busisiwe Cele', 'Lerato Modise', 'Lerato Mahlangu', 'Sipho Botha',
#        'Ayanda Mkhize', 'Ayanda Ngcobo', 'Ayanda Dlamini',
#        'Lwazi Sithole', 'Precious Molefe', 'Busisiwe Naidoo',
#        'Lerato Khumalo', 'Nandi Van Wyk', 'Bongani Botha',
#        'Tshepo Sithole', 'Tshepo Mahlangu', 'Nandi Nkosi',
#        'Bongani Sithole', 'Sipho Sithole', 'Busisiwe Pillay',
#        'Themba Maseko', 'Mandla Adams', 'Lerato Mthembu', 'Karabo Cele',
#        'Lwazi Mabena', 'Lwazi Adams', 'Precious Mokoena',
#        'Mandla Williams', 'Precious Sithole', 'Siyabonga Maseko',
#        'Tshepo Ngcobo', 'Nomsa Pillay', 'Siyabonga Zulu',
#        'Amanda Williams', 'Nandi Mthembu', 'Thabo Van Wyk',
#        'Ayanda Jacobs', 'Lwazi Cele', 'Nomsa Ngcobo', 'Phumzile Ndlovu',
#        'Mpho Van Wyk', 'Bongani Modise', 'Thabo Mokoena',
#        'Phumzile Nkosi', 'Kagiso Van Wyk', 'Ayanda Molefe',
#        'Sipho Khumalo', 'Mandla Botha', 'Sibusiso Mthembu',
#        'Lwazi Van Wyk', 'Mandla Mthembu', 'Siyabonga Mkhize',
#        'Dumisani Pillay', 'Ayanda Ndlovu', 'Bongani Jacobs',
#        'Thabo Nkosi', 'Busisiwe Sithole', 'Nokuthula Adams',
#        'Bongani Moyo', 'Phumzile Maseko', 'Nomsa Cele', 'Ayanda Maseko',
#        'Lwazi Molefe', 'Siyabonga Botha', 'Nomsa Mkhize', 'Lerato Zulu',
#        'Dumisani Ngcobo', 'Karabo Van Wyk', 'Kabelo Mabena',
#        'Lerato Adams', 'Precious Van Wyk', 'Amanda Zulu', 'Zanele Naidoo',
#        'Karabo Zulu', 'Thabo Moyo', 'Nomsa Williams', 'Busisiwe Zulu',
#        'Sipho Mkhize', 'Zanele Maseko'], dtype=object)

# %%
drivers.age.unique()
# Out:
# array([47, 59, 37, 38, 50, 46, 45, 52, 41, 63, 55, 24, 40, 31, 26, 60, 39,
#        23, 53, 57, 29, 61, 48, 56, 33, 54, 32, 65, 28, 35, 64, 42, 62, 43,
#        30, 36, 34, 27, 58, 49, 51, 25, 44])

# %%
drivers.experience_years.unique()
# Out:
# array([34, 25,  6, 23,  3, 22,  9, 20, 12, 21, 13, 30, 15, 17, 26,  4, 27,
#         2, 16, 33, 24, 19,  5, 28,  8, 14, 11, 18,  1, 32, 29,  7, 31, 10])

# %%
drivers.license_type.unique()
# Out:
# array(['Code 10', 'Code 14', 'Code 8'], dtype=object)

# %%
drivers.employment_type.unique()
# Out:
# array(['Contract', 'Permanent', 'Owner Driver'], dtype=object)

# %%
drivers.home_province.unique()
# Out:
# array(['North West', 'Western Cape', 'Free State', 'Mpumalanga',
#        'Gauteng', 'Limpopo', 'Northern Cape', 'Eastern Cape',
#        'KwaZulu-Natal'], dtype=object)

# %%
drivers.performance_rating.unique()
# Out:
# array([3.51, 3.28, 4.59, 4.31, 3.8 , 4.6 , 3.36, 4.96, 3.71, 3.14, 4.66,
#        4.93, 4.45, 3.24, 4.3 , 3.89, 3.46, 3.67, 3.73, 4.17, 4.1 , 3.4 ,
#        4.22, 3.97, 3.1 , 3.94, 3.76, 4.89, 4.21, 2.67, 4.79, 3.12, 3.93,
#        4.15, 3.75, 3.92, 3.01, 4.67, 3.13, 4.95, 4.29, 3.35, 3.17, 4.52,
#        3.44, 4.02, 3.66, 4.4 , 3.65, 4.14, 3.52, 3.11, 3.45, 2.56, 4.61,
#        3.88, 3.57, 4.03, 3.85, 3.37, 3.95, 4.35, 4.28, 4.27, 4.11, 3.83,
#        4.34, 5.  , 3.81, 4.57, 3.55, 3.5 , 3.87, 4.63, 3.64, 3.34, 3.82,
#        4.2 , 4.65, 3.43, 4.53, 3.06, 4.49, 4.  , 2.93, 4.05, 4.64, 4.56,
#        4.12, 3.42, 4.07, 2.78, 4.08, 3.3 , 4.75, 4.06, 3.19, 4.62, 3.96,
#        4.55, 3.7 , 4.13, 2.89, 3.62, 3.74, 3.78, 4.25, 3.26, 4.37, 4.69,
#        4.23, 2.85, 3.79, 4.26, 4.47, 3.98, 3.33, 4.16, 3.99, 4.84, 3.56,
#        3.77, 3.47, 4.72, 3.91, 3.61, 3.16, 3.69, 4.04, 4.42, 3.49, 2.82,
#        4.09, 2.77, 4.39, 4.76, 4.01, 3.22, 3.53, 4.7 , 3.18, 4.46, 3.27,
#        3.38, 4.18, 4.33, 3.68, 3.84, 3.63, 2.92, 4.36, 4.32, 3.39, 3.2 ,
#        2.95, 4.48, 3.15, 3.6 , 4.71, 4.19, 4.51, 4.41, 3.  , 4.83, 2.99,
#        4.99, 3.9 , 3.32, 4.58, 3.58, 3.54, 4.98, 4.92, 2.96, 2.71, 4.5 ,
#        3.48, 2.81, 4.68, 2.98, 2.91, 4.54, 4.73, 4.24, 4.86, 4.44, 3.04,
#        3.08, 3.72, 4.77, 4.88, 4.94, 3.29, 4.38, 3.31, 2.9 , 3.86, 4.43,
#        3.23, 2.79, 4.91, 3.09, 3.21, 2.83, 3.07, 3.59, 3.03, 4.9 , 4.8 ,
#        3.41, 4.82, 2.73, 2.74, 2.64, 4.74, 3.02, 2.54, 2.88, 4.78, 2.63,
#        2.5 , 2.84, 4.87, 2.75, 4.85, 2.8 , 4.81, 4.97, 2.87, 2.62, 3.25,
#        2.41, 2.72, 2.66, 2.61, 2.94, 3.05, 2.7 , 2.42, 2.69, 2.39, 2.43,
#        2.97, 2.65, 2.57, 2.68, 2.53, 2.6 , 2.31, 2.86, 1.68, 2.37, 2.46,
#        2.52, 2.48, 2.44, 1.85, 2.4 , 2.76, 2.38, 2.23, 2.51, 2.16, 1.83,
#        2.45, 2.58, 2.55, 2.  , 2.47])

# %% [markdown]
# # Inspecting Warehouses and Cleaning Data

# %%
import pandas as pd
warehouses = pd.read_csv("supplyguard_data/warehouses.csv")
warehouses
# Out:
#     warehouse_id                          warehouse_name          city  \
# 0         W00001           SupplyGuard Paarl Warehouse 1         Paarl
# 1         W00002     SupplyGuard Grahamstown Warehouse 2   Grahamstown
# 2         W00003       SupplyGuard Polokwane Warehouse 3     Polokwane
# 3         W00004    SupplyGuard Bloemfontein Warehouse 4  Bloemfontein
# 4         W00005      SupplyGuard Rustenburg Warehouse 5    Rustenburg
# ..           ...                                     ...           ...
# 245       W00246   SupplyGuard Grahamstown Warehouse 246   Grahamstown
# 246       W00247     SupplyGuard Polokwane Warehouse 247     Polokwane
# 247       W00248   SupplyGuard Thohoyandou Warehouse 248   Thohoyandou
# 248       W00249  SupplyGuard Johannesburg Warehouse 249  Johannesburg
# 249       W00250      SupplyGuard Mahikeng Warehouse 250      Mahikeng
#
#          province warehouse_type  capacity_units
# 0    Western Cape   Distribution           79458
# 1    Eastern Cape   Cold Storage           74606
# 2         Limpopo   Cold Storage          106359
# 3      Free State       Regional           49522
# 4      North West     Fulfilment          240013
# ..            ...            ...             ...
# 245  Eastern Cape     Cross-Dock          484898
# 246       Limpopo   Distribution          388641
# 247       Limpopo   Distribution          249748
# 248       Gauteng   Cold Storage          362366
# 249    North West   Distribution          436323
#
# [250 rows x 6 columns]

# %%
warehouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   warehouse_id    250 non-null    object
#  1   warehouse_name  250 non-null    object
#  2   city            250 non-null    object
#  3   province        250 non-null    object
#  4   warehouse_type  250 non-null    object
#  5   capacity_units  250 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 11.8+ KB

# %%
warehouses.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Length: 250, dtype: bool

# %%
warehouses[warehouses.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [warehouse_id, warehouse_name, city, province, warehouse_type, capacity_units]
# Index: []

# %%
warehouses.columns
# Out:
# Index(['warehouse_id', 'warehouse_name', 'city', 'province', 'warehouse_type',
#        'capacity_units'],
#       dtype='object')

# %%
warehouses.warehouse_name.unique()
# Out:
# array(['SupplyGuard Paarl Warehouse 1',
#        'SupplyGuard Grahamstown Warehouse 2',
#        'SupplyGuard Polokwane Warehouse 3',
#        'SupplyGuard Bloemfontein Warehouse 4',
#        'SupplyGuard Rustenburg Warehouse 5',
#        'SupplyGuard Witbank Warehouse 6',
#        'SupplyGuard Gqeberha Warehouse 7',
#        'SupplyGuard Mbombela Warehouse 8',
#        'SupplyGuard Mbombela Warehouse 9',
#        'SupplyGuard Bloemfontein Warehouse 10',
#        'SupplyGuard Kroonstad Warehouse 11',
#        'SupplyGuard Kuruman Warehouse 12',
#        'SupplyGuard Kimberley Warehouse 13',
#        'SupplyGuard Mthatha Warehouse 14',
#        'SupplyGuard Mahikeng Warehouse 15',
#        'SupplyGuard Richards Bay Warehouse 16',
#        'SupplyGuard Potchefstroom Warehouse 17',
#        'SupplyGuard Nelspruit Warehouse 18',
#        'SupplyGuard Polokwane Warehouse 19',
#        'SupplyGuard Umhlanga Warehouse 20',
#        'SupplyGuard Mbombela Warehouse 21',
#        'SupplyGuard Polokwane Warehouse 22',
#        'SupplyGuard Gqeberha Warehouse 23',
#        'SupplyGuard Upington Warehouse 24',
#        'SupplyGuard Potchefstroom Warehouse 25',
#        'SupplyGuard Upington Warehouse 26',
#        'SupplyGuard Kuruman Warehouse 27',
#        'SupplyGuard Pietermaritzburg Warehouse 28',
#        'SupplyGuard Gqeberha Warehouse 29',
#        'SupplyGuard Rustenburg Warehouse 30',
#        'SupplyGuard George Warehouse 31',
#        'SupplyGuard Polokwane Warehouse 32',
#        'SupplyGuard Soweto Warehouse 33',
#        'SupplyGuard Witbank Warehouse 34',
#        'SupplyGuard Kroonstad Warehouse 35',
#        'SupplyGuard Centurion Warehouse 36',
#        'SupplyGuard Rustenburg Warehouse 37',
#        'SupplyGuard Mthatha Warehouse 38',
#        'SupplyGuard Mbombela Warehouse 39',
#        'SupplyGuard Bloemfontein Warehouse 40',
#        'SupplyGuard Welkom Warehouse 41',
#        'SupplyGuard Gqeberha Warehouse 42',
#        'SupplyGuard Grahamstown Warehouse 43',
#        'SupplyGuard Mthatha Warehouse 44',
#        'SupplyGuard Kroonstad Warehouse 45',
#        'SupplyGuard Centurion Warehouse 46',
#        'SupplyGuard Mthatha Warehouse 47',
#        'SupplyGuard Bellville Warehouse 48',
#        'SupplyGuard Soweto Warehouse 49',
#        'SupplyGuard Nelspruit Warehouse 50',
#        'SupplyGuard Rustenburg Warehouse 51',
#        'SupplyGuard Cape Town Warehouse 52',
#        'SupplyGuard Klerksdorp Warehouse 53',
#        'SupplyGuard Newcastle Warehouse 54',
#        'SupplyGuard Bloemfontein Warehouse 55',
#        'SupplyGuard Cape Town Warehouse 56',
#        'SupplyGuard East London Warehouse 57',
#        'SupplyGuard Mthatha Warehouse 58',
#        'SupplyGuard Sandton Warehouse 59',
#        'SupplyGuard Mbombela Warehouse 60',
#        'SupplyGuard Kimberley Warehouse 61',
#        'SupplyGuard Welkom Warehouse 62',
#        'SupplyGuard Soweto Warehouse 63',
#        'SupplyGuard Newcastle Warehouse 64',
#        'SupplyGuard Welkom Warehouse 65',
#        'SupplyGuard Upington Warehouse 66',
#        'SupplyGuard George Warehouse 67',
#        'SupplyGuard Middelburg Warehouse 68',
#        'SupplyGuard Pretoria Warehouse 69',
#        'SupplyGuard Umhlanga Warehouse 70',
#        'SupplyGuard Upington Warehouse 71',
#        'SupplyGuard Nelspruit Warehouse 72',
#        'SupplyGuard Mbombela Warehouse 73',
#        'SupplyGuard Mthatha Warehouse 74',
#        'SupplyGuard Johannesburg Warehouse 75',
#        'SupplyGuard Nelspruit Warehouse 76',
#        'SupplyGuard Gqeberha Warehouse 77',
#        'SupplyGuard Witbank Warehouse 78',
#        'SupplyGuard Pietermaritzburg Warehouse 79',
#        'SupplyGuard Cape Town Warehouse 80',
#        'SupplyGuard Welkom Warehouse 81',
#        'SupplyGuard Kimberley Warehouse 82',
#        'SupplyGuard Thohoyandou Warehouse 83',
#        'SupplyGuard Mbombela Warehouse 84',
#        'SupplyGuard Kuruman Warehouse 85',
#        'SupplyGuard Sandton Warehouse 86',
#        'SupplyGuard Kuruman Warehouse 87',
#        'SupplyGuard Durban Warehouse 88',
#        'SupplyGuard Bellville Warehouse 89',
#        'SupplyGuard Newcastle Warehouse 90',
#        'SupplyGuard Nelspruit Warehouse 91',
#        'SupplyGuard Middelburg Warehouse 92',
#        'SupplyGuard Witbank Warehouse 93',
#        'SupplyGuard Paarl Warehouse 94',
#        'SupplyGuard Pietermaritzburg Warehouse 95',
#        'SupplyGuard Polokwane Warehouse 96',
#        'SupplyGuard Witbank Warehouse 97',
#        'SupplyGuard Cape Town Warehouse 98',
#        'SupplyGuard Umhlanga Warehouse 99',
#        'SupplyGuard Kuruman Warehouse 100',
#        'SupplyGuard Upington Warehouse 101',
#        'SupplyGuard Soweto Warehouse 102',
#        'SupplyGuard Kroonstad Warehouse 103',
#        'SupplyGuard Welkom Warehouse 104',
#        'SupplyGuard Upington Warehouse 105',
#        'SupplyGuard Richards Bay Warehouse 106',
#        'SupplyGuard Kroonstad Warehouse 107',
#        'SupplyGuard Upington Warehouse 108',
#        'SupplyGuard Paarl Warehouse 109',
#        'SupplyGuard Richards Bay Warehouse 110',
#        'SupplyGuard Cape Town Warehouse 111',
#        'SupplyGuard Sandton Warehouse 112',
#        'SupplyGuard Durban Warehouse 113',
#        'SupplyGuard Bloemfontein Warehouse 114',
#        'SupplyGuard George Warehouse 115',
#        'SupplyGuard Upington Warehouse 116',
#        'SupplyGuard Polokwane Warehouse 117',
#        'SupplyGuard Cape Town Warehouse 118',
#        'SupplyGuard Klerksdorp Warehouse 119',
#        'SupplyGuard Bellville Warehouse 120',
#        'SupplyGuard Mahikeng Warehouse 121',
#        'SupplyGuard Mahikeng Warehouse 122',
#        'SupplyGuard Stellenbosch Warehouse 123',
#        'SupplyGuard Klerksdorp Warehouse 124',
#        'SupplyGuard Kroonstad Warehouse 125',
#        'SupplyGuard Polokwane Warehouse 126',
#        'SupplyGuard Upington Warehouse 127',
#        'SupplyGuard Rustenburg Warehouse 128',
#        'SupplyGuard Kuruman Warehouse 129',
#        'SupplyGuard Pietermaritzburg Warehouse 130',
#        'SupplyGuard Kuruman Warehouse 131',
#        'SupplyGuard Rustenburg Warehouse 132',
#        'SupplyGuard Witbank Warehouse 133',
#        'SupplyGuard Kroonstad Warehouse 134',
#        'SupplyGuard Gqeberha Warehouse 135',
#        'SupplyGuard Middelburg Warehouse 136',
#        'SupplyGuard Stellenbosch Warehouse 137',
#        'SupplyGuard Cape Town Warehouse 138',
#        'SupplyGuard Grahamstown Warehouse 139',
#        'SupplyGuard Middelburg Warehouse 140',
#        'SupplyGuard Umhlanga Warehouse 141',
#        'SupplyGuard Upington Warehouse 142',
#        'SupplyGuard Umhlanga Warehouse 143',
#        'SupplyGuard Bloemfontein Warehouse 144',
#        'SupplyGuard Polokwane Warehouse 145',
#        'SupplyGuard Bellville Warehouse 146',
#        'SupplyGuard Mbombela Warehouse 147',
#        'SupplyGuard Potchefstroom Warehouse 148',
#        'SupplyGuard Potchefstroom Warehouse 149',
#        'SupplyGuard Tzaneen Warehouse 150',
#        'SupplyGuard Welkom Warehouse 151',
#        'SupplyGuard Umhlanga Warehouse 152',
#        'SupplyGuard Mthatha Warehouse 153',
#        'SupplyGuard Nelspruit Warehouse 154',
#        'SupplyGuard Witbank Warehouse 155',
#        'SupplyGuard Mthatha Warehouse 156',
#        'SupplyGuard Witbank Warehouse 157',
#        'SupplyGuard Kuruman Warehouse 158',
#        'SupplyGuard Cape Town Warehouse 159',
#        'SupplyGuard Middelburg Warehouse 160',
#        'SupplyGuard Middelburg Warehouse 161',
#        'SupplyGuard Nelspruit Warehouse 162',
#        'SupplyGuard Klerksdorp Warehouse 163',
#        'SupplyGuard Thohoyandou Warehouse 164',
#        'SupplyGuard Potchefstroom Warehouse 165',
#        'SupplyGuard Kimberley Warehouse 166',
#        'SupplyGuard Bellville Warehouse 167',
#        'SupplyGuard Pretoria Warehouse 168',
#        'SupplyGuard Witbank Warehouse 169',
#        'SupplyGuard Thohoyandou Warehouse 170',
#        'SupplyGuard Mahikeng Warehouse 171',
#        'SupplyGuard Pietermaritzburg Warehouse 172',
#        'SupplyGuard Bellville Warehouse 173',
#        'SupplyGuard George Warehouse 174',
#        'SupplyGuard Middelburg Warehouse 175',
#        'SupplyGuard Welkom Warehouse 176',
#        'SupplyGuard Klerksdorp Warehouse 177',
#        'SupplyGuard Stellenbosch Warehouse 178',
#        'SupplyGuard Midrand Warehouse 179',
#        'SupplyGuard Grahamstown Warehouse 180',
#        'SupplyGuard Durban Warehouse 181',
#        'SupplyGuard Centurion Warehouse 182',
#        'SupplyGuard Potchefstroom Warehouse 183',
#        'SupplyGuard Paarl Warehouse 184',
#        'SupplyGuard Welkom Warehouse 185',
#        'SupplyGuard Kuruman Warehouse 186',
#        'SupplyGuard Kimberley Warehouse 187',
#        'SupplyGuard Rustenburg Warehouse 188',
#        'SupplyGuard Tzaneen Warehouse 189',
#        'SupplyGuard Upington Warehouse 190',
#        'SupplyGuard Gqeberha Warehouse 191',
#        'SupplyGuard Polokwane Warehouse 192',
#        'SupplyGuard Rustenburg Warehouse 193',
#        'SupplyGuard Rustenburg Warehouse 194',
#        'SupplyGuard Grahamstown Warehouse 195',
#        'SupplyGuard Kuruman Warehouse 196',
#        'SupplyGuard Worcester Warehouse 197',
#        'SupplyGuard Thohoyandou Warehouse 198',
#        'SupplyGuard Klerksdorp Warehouse 199',
#        'SupplyGuard Pretoria Warehouse 200',
#        'SupplyGuard Johannesburg Warehouse 201',
#        'SupplyGuard East London Warehouse 202',
#        'SupplyGuard Upington Warehouse 203',
#        'SupplyGuard Bloemfontein Warehouse 204',
#        'SupplyGuard Middelburg Warehouse 205',
#        'SupplyGuard Kimberley Warehouse 206',
#        'SupplyGuard Upington Warehouse 207',
#        'SupplyGuard Richards Bay Warehouse 208',
#        'SupplyGuard Middelburg Warehouse 209',
#        'SupplyGuard East London Warehouse 210',
#        'SupplyGuard Centurion Warehouse 211',
#        'SupplyGuard Soweto Warehouse 212',
#        'SupplyGuard Worcester Warehouse 213',
#        'SupplyGuard Grahamstown Warehouse 214',
#        'SupplyGuard Bloemfontein Warehouse 215',
#        'SupplyGuard Welkom Warehouse 216',
#        'SupplyGuard Soweto Warehouse 217',
#        'SupplyGuard Grahamstown Warehouse 218',
#        'SupplyGuard Upington Warehouse 219',
#        'SupplyGuard East London Warehouse 220',
#        'SupplyGuard Upington Warehouse 221',
#        'SupplyGuard Witbank Warehouse 222',
#        'SupplyGuard Gqeberha Warehouse 223',
#        'SupplyGuard Mahikeng Warehouse 224',
#        'SupplyGuard Umhlanga Warehouse 225',
#        'SupplyGuard Stellenbosch Warehouse 226',
#        'SupplyGuard Centurion Warehouse 227',
#        'SupplyGuard Centurion Warehouse 228',
#        'SupplyGuard Centurion Warehouse 229',
#        'SupplyGuard Welkom Warehouse 230',
#        'SupplyGuard Umhlanga Warehouse 231',
#        'SupplyGuard Kuruman Warehouse 232',
#        'SupplyGuard Paarl Warehouse 233',
#        'SupplyGuard Centurion Warehouse 234',
#        'SupplyGuard Johannesburg Warehouse 235',
#        'SupplyGuard Upington Warehouse 236',
#        'SupplyGuard Kroonstad Warehouse 237',
#        'SupplyGuard Gqeberha Warehouse 238',
#        'SupplyGuard Bloemfontein Warehouse 239',
#        'SupplyGuard Rustenburg Warehouse 240',
#        'SupplyGuard Kuruman Warehouse 241',
#        'SupplyGuard Grahamstown Warehouse 242',
#        'SupplyGuard Kuruman Warehouse 243',
#        'SupplyGuard Mahikeng Warehouse 244',
#        'SupplyGuard Mahikeng Warehouse 245',
#        'SupplyGuard Grahamstown Warehouse 246',
#        'SupplyGuard Polokwane Warehouse 247',
#        'SupplyGuard Thohoyandou Warehouse 248',
#        'SupplyGuard Johannesburg Warehouse 249',
#        'SupplyGuard Mahikeng Warehouse 250'], dtype=object)

# %%
warehouses.city.unique()
# Out:
# array(['Paarl', 'Grahamstown', 'Polokwane', 'Bloemfontein', 'Rustenburg',
#        'Witbank', 'Gqeberha', 'Mbombela', 'Kroonstad', 'Kuruman',
#        'Kimberley', 'Mthatha', 'Mahikeng', 'Richards Bay',
#        'Potchefstroom', 'Nelspruit', 'Umhlanga', 'Upington',
#        'Pietermaritzburg', 'George', 'Soweto', 'Centurion', 'Welkom',
#        'Bellville', 'Cape Town', 'Klerksdorp', 'Newcastle', 'East London',
#        'Sandton', 'Middelburg', 'Pretoria', 'Johannesburg', 'Thohoyandou',
#        'Durban', 'Stellenbosch', 'Tzaneen', 'Midrand', 'Worcester'],
#       dtype=object)

# %%
warehouses.province.unique()
# Out:
# array(['Western Cape', 'Eastern Cape', 'Limpopo', 'Free State',
#        'North West', 'Mpumalanga', 'Northern Cape', 'KwaZulu-Natal',
#        'Gauteng'], dtype=object)

# %%
warehouses.warehouse_type.unique()
# Out:
# array(['Distribution', 'Cold Storage', 'Regional', 'Fulfilment',
#        'Cross-Dock'], dtype=object)

# %%
warehouses.capacity_units.unique()
# Out:
# array([ 79458,  74606, 106359,  49522, 240013,  11370,  30469,  79188,
#        137909, 240715, 225049, 231363, 456731,  27539, 232052, 320519,
#        417720, 181633, 258591, 126015, 128814, 467183, 321836, 483191,
#         77289, 484231, 287556, 418715, 480695, 131038, 380059, 190043,
#        310979, 289148, 262485, 154402, 493911, 350774,  93380, 133075,
#         81328, 123954, 153678, 230256, 264316, 183455, 123031, 139605,
#        164041,  31544, 183752,  78119, 341463, 197192, 266078, 220420,
#        319731, 247432, 227549, 312638,  35163, 215090, 118048, 483668,
#         49663, 131191,  31135, 107085, 426343, 420059, 224122,  58586,
#        386243, 378887,  76455, 316420,  25304, 344023, 125270, 424835,
#        163719, 223531, 345143, 360585, 336858,  27130, 331731, 446419,
#        295744, 386801, 182333, 216189,  99354, 295492, 346961, 155645,
#        240890, 410769, 470356, 471285, 354823, 279397, 470112, 204785,
#        186670, 120489, 391939, 118000, 269212, 432489, 440995,  86922,
#        426671, 115530, 468553, 450244, 420638, 439878, 335038, 479838,
#        309863, 429290, 219548, 434133,  75450, 168068, 101446, 372036,
#        392608, 431913, 276130, 232857,  82127, 194003, 153554, 113336,
#        486876, 199554, 436402, 266334, 221661,  42625, 146239,  71603,
#        225174, 452042, 273265, 438748, 497227, 416142, 146757, 491485,
#        166873, 228275, 261985, 345445,  86068,  29258, 376082, 456255,
#        173172, 337308,  77405, 245539, 448459, 422457, 113944,  77315,
#         75591, 183556, 484657, 334859,  68223, 115315, 393401, 350931,
#         90156, 117215, 257990, 401229, 392978, 382480, 418099, 211833,
#        134732,  71929,  78579, 279889, 252464,   5104, 167963, 312418,
#        392138,  44366,  58685,  56185, 110659, 446976, 377265, 388632,
#        472403, 402667, 291051, 400371, 237545, 232584, 218505, 306003,
#        399009, 207511, 273220,  49342,  36703, 232599, 289484, 251841,
#        304751, 136745, 221459, 209643, 335040,  39893, 259207, 178003,
#        192775, 217923, 316228, 369369, 116050, 361039, 370346, 106556,
#        275913, 330717, 323351, 428791, 156581, 251564, 495930, 128527,
#         58661, 209755, 273365, 107997, 368596, 484898, 388641, 249748,
#        362366, 436323])

# %% [markdown]
# # Inspecting Data Dictionary and Cleaning Data

# %%
import pandas as pd
data_dictionary = pd.read_csv("supplyguard_data/data_dictionary.csv")
data_dictionary
# Out:
#                 dataset                   column  \
# 0         customers.csv              customer_id
# 1         customers.csv            customer_name
# 2         customers.csv            customer_type
# 3         customers.csv                 province
# 4         customers.csv                     city
# 5         customers.csv        registration_date
# 6         customers.csv  monthly_shipping_budget
# 7         shipments.csv              shipment_id
# 8         shipments.csv              customer_id
# 9         shipments.csv             warehouse_id
# 10        shipments.csv            shipment_date
# 11        shipments.csv            shipment_type
# 12        shipments.csv          delivery_method
# 13        shipments.csv                weight_kg
# 14        shipments.csv       declared_value_zar
# 15        shipments.csv              distance_km
# 16        shipments.csv                 priority
# 17       deliveries.csv              delivery_id
# 18       deliveries.csv              shipment_id
# 19       deliveries.csv                driver_id
# 20       deliveries.csv               vehicle_id
# 21       deliveries.csv            delivery_date
# 22       deliveries.csv          delivery_status
# 23       deliveries.csv  delivery_duration_hours
# 24       deliveries.csv     delivery_distance_km
# 25       deliveries.csv            fuel_cost_zar
# 26       deliveries.csv          customer_rating
# 27       deliveries.csv           attempt_number
# 28       deliveries.csv            delivery_hour
# 29          drivers.csv                driver_id
# 30          drivers.csv              driver_name
# 31          drivers.csv                      age
# 32          drivers.csv         experience_years
# 33          drivers.csv             license_type
# 34          drivers.csv          employment_type
# 35          drivers.csv            home_province
# 36          drivers.csv       performance_rating
# 37         vehicles.csv               vehicle_id
# 38         vehicles.csv             vehicle_type
# 39         vehicles.csv        vehicle_age_years
# 40         vehicles.csv              capacity_kg
# 41         vehicles.csv                fuel_type
# 42         vehicles.csv        maintenance_score
# 43         vehicles.csv       current_mileage_km
# 44       warehouses.csv             warehouse_id
# 45       warehouses.csv           warehouse_name
# 46       warehouses.csv                     city
# 47       warehouses.csv                 province
# 48       warehouses.csv           warehouse_type
# 49       warehouses.csv           capacity_units
# 50  delivery_labels.csv              delivery_id
# 51  delivery_labels.csv                  is_late
# 52  delivery_labels.csv              risk_reason
# 53   exchange_rates.csv                     date
# 54   exchange_rates.csv                 currency
# 55   exchange_rates.csv                 zar_rate
#
#                                     description
# 0                    Unique customer identifier
# 1                                 Customer name
# 2   Individual, business or enterprise customer
# 3                             Customer province
# 4                                 Customer city
# 5                    Customer registration date
# 6            Estimated monthly logistics budget
# 7                    Unique shipment identifier
# 8                 Customer placing the shipment
# 9                              Origin warehouse
# 10                    Date shipment was created
# 11                             Type of shipment
# 12                              Delivery method
# 13                              Shipment weight
# 14                      Declared shipment value
# 15                   Expected shipment distance
# 16                            Shipment priority
# 17                   Unique delivery identifier
# 18                     Shipment being delivered
# 19                              Assigned driver
# 20                             Assigned vehicle
# 21                                Delivery date
# 22                              Delivery status
# 23                            Delivery duration
# 24                     Actual delivery distance
# 25                          Estimated fuel cost
# 26                     Customer delivery rating
# 27                  Number of delivery attempts
# 28                     Hour delivery took place
# 29                     Unique driver identifier
# 30                                  Driver name
# 31                                   Driver age
# 32                           Driving experience
# 33                     Driving licence category
# 34                       Employment arrangement
# 35                         Driver home province
# 36          Synthetic driver performance rating
# 37                    Unique vehicle identifier
# 38                             Vehicle category
# 39                                  Vehicle age
# 40                    Vehicle carrying capacity
# 41                                    Fuel type
# 42                    Vehicle maintenance score
# 43                              Vehicle mileage
# 44                  Unique warehouse identifier
# 45                               Warehouse name
# 46                               Warehouse city
# 47                           Warehouse province
# 48                           Warehouse category
# 49                           Warehouse capacity
# 50                          Delivery identifier
# 51            Synthetic late-delivery indicator
# 52                 Explainable synthetic reason
# 53                           Exchange-rate date
# 54                                     Currency
# 55                Approximate ZAR exchange rate

# %%
data_dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dataset      56 non-null     object
#  1   column       56 non-null     object
#  2   description  56 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
data_dictionary.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# dtype: bool

# %%
data_dictionary[data_dictionary.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [dataset, column, description]
# Index: []

# %%
data_dictionary.columns
# Out:
# Index(['dataset', 'column', 'description'], dtype='object')

# %%
data_dictionary.dataset.unique()
# Out:
# array(['customers.csv', 'shipments.csv', 'deliveries.csv', 'drivers.csv',
#        'vehicles.csv', 'warehouses.csv', 'delivery_labels.csv',
#        'exchange_rates.csv'], dtype=object)

# %%
data_dictionary.column.unique()
# Out:
# array(['customer_id', 'customer_name', 'customer_type', 'province',
#        'city', 'registration_date', 'monthly_shipping_budget',
#        'shipment_id', 'warehouse_id', 'shipment_date', 'shipment_type',
#        'delivery_method', 'weight_kg', 'declared_value_zar',
#        'distance_km', 'priority', 'delivery_id', 'driver_id',
#        'vehicle_id', 'delivery_date', 'delivery_status',
#        'delivery_duration_hours', 'delivery_distance_km', 'fuel_cost_zar',
#        'customer_rating', 'attempt_number', 'delivery_hour',
#        'driver_name', 'age', 'experience_years', 'license_type',
#        'employment_type', 'home_province', 'performance_rating',
#        'vehicle_type', 'vehicle_age_years', 'capacity_kg', 'fuel_type',
#        'maintenance_score', 'current_mileage_km', 'warehouse_name',
#        'warehouse_type', 'capacity_units', 'is_late', 'risk_reason',
#        'date', 'currency', 'zar_rate'], dtype=object)

# %%
data_dictionary.description.unique()
# Out:
# array(['Unique customer identifier', 'Customer name',
#        'Individual, business or enterprise customer', 'Customer province',
#        'Customer city', 'Customer registration date',
#        'Estimated monthly logistics budget', 'Unique shipment identifier',
#        'Customer placing the shipment', 'Origin warehouse',
#        'Date shipment was created', 'Type of shipment', 'Delivery method',
#        'Shipment weight', 'Declared shipment value',
#        'Expected shipment distance', 'Shipment priority',
#        'Unique delivery identifier', 'Shipment being delivered',
#        'Assigned driver', 'Assigned vehicle', 'Delivery date',
#        'Delivery status', 'Delivery duration', 'Actual delivery distance',
#        'Estimated fuel cost', 'Customer delivery rating',
#        'Number of delivery attempts', 'Hour delivery took place',
#        'Unique driver identifier', 'Driver name', 'Driver age',
#        'Driving experience', 'Driving licence category',
#        'Employment arrangement', 'Driver home province',
#        'Synthetic driver performance rating', 'Unique vehicle identifier',
#        'Vehicle category', 'Vehicle age', 'Vehicle carrying capacity',
#        'Fuel type', 'Vehicle maintenance score', 'Vehicle mileage',
#        'Unique warehouse identifier', 'Warehouse name', 'Warehouse city',
#        'Warehouse province', 'Warehouse category', 'Warehouse capacity',
#        'Delivery identifier', 'Synthetic late-delivery indicator',
#        'Explainable synthetic reason', 'Exchange-rate date', 'Currency',
#        'Approximate ZAR exchange rate'], dtype=object)

# %% [markdown]
# # Inspecting Delivery labels and Cleanging Data

# %%
import pandas as pd
delivery_labels = pd.read_csv("supplyguard_data/delivery_labels.csv")
delivery_labels
# Out:
#         delivery_id  is_late             risk_reason
# 0       DL000000001        1  Long delivery distance
# 1       DL000000002        0         Normal delivery
# 2       DL000000003        0         Normal delivery
# 3       DL000000004        0         Normal delivery
# 4       DL000000005        0         Normal delivery
# ...             ...      ...                     ...
# 999995  DL000999996        0         Normal delivery
# 999996  DL000999997        0         Normal delivery
# 999997  DL000999998        0         Normal delivery
# 999998  DL000999999        0         Normal delivery
# 999999  DL001000000        0         Normal delivery
#
# [1000000 rows x 3 columns]

# %%
delivery_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   delivery_id  1000000 non-null  object
#  1   is_late      1000000 non-null  int64
#  2   risk_reason  1000000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 22.9+ MB

# %%
delivery_labels.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
delivery_labels[delivery_labels.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [delivery_id, is_late, risk_reason]
# Index: []

# %%
delivery_labels.columns
# Out:
# Index(['delivery_id', 'is_late', 'risk_reason'], dtype='object')

# %%
delivery_labels.is_late.unique()
# Out:
# array([1, 0])

# %%
delivery_labels.risk_reason.unique()
# Out:
# array(['Long delivery distance', 'Normal delivery', 'Operational delay',
#        'Low driver performance', 'Poor vehicle maintenance',
#        'Early delivery', 'Late delivery hour'], dtype=object)
