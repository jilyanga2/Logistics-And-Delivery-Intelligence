# %% [markdown]
# # Shipment Feature Engineering

# %%
import pandas as pd
shipments = pd.read_csv("cleaned_supplyguard_data/shipments_cleaned.csv")
shipments

# %%
print(shipments["shipment_date"].head())
print(shipments["shipment_date"].dtype)
# Out:
# 0    2025-12-14
# 1    2025-03-21
# 2    2026-06-23
# 3    2026-07-21
# 4    2025-07-15
# Name: shipment_date, dtype: object
# object

# %%
shipments["shipment_date"] = pd.to_datetime(shipments["shipment_date"]).dt.date

# %%
print("SHIPMENTS:")
print(shipments.columns.tolist())
print("Number of rows:"), len(shipments)
# Out:
# SHIPMENTS:
# ['shipment_id', 'customer_id', 'warehouse_id', 'shipment_date', 'shipment_type', 'delivery_method', 'weight_kg', 'declared_value_zar', 'distance_km', 'priority', 'year', 'month', 'day', 'weekday', 'hour', 'weekend']

# %%
shipments.head()
