# %% [markdown]
# # Customer Findings

# %% [markdown]
# # Shipment Findings

# %% [markdown]
# # Vehicle Findings

# %% [markdown]
# # Exchange Rate Findings

# %% [markdown]
# # Deliveries Findings

# %% [markdown]
# # Drivers Findings

# %% [markdown]
# # Warehouse Findings

# %% [markdown]
# # Data Dictionary Findings

# %% [markdown]
# # Delivery Labels Findings
